# %%
import requests
import json
import pandas as pd
import csv
from pprint import pprint

# %%
csvpath="Resources/busiest_us_airport_codes.csv"
busyairportdf=pd.read_csv(csvpath)
busyairportdf
# Out:
#                                          Airport Name Code  \
# 0    Hartsfield Jackson Atlanta International Airport  ATL
# 1                        O'Hare International Airport  ORD
# 2                   Los Angeles International Airport  LAX
# 3             Dallas/Fort Worth International Airport  DFW
# 4                        Denver International Airport  DEN
# 5               John F. Kennedy International Airport  JFK
# 6                George Bush Intercontinental Airport  IAH
# 7                 San Francisco International Airport  SFO
# 8                      McCarran International Airport  LAS
# 9            Phoenix Sky Harbor International Airport  PHX
# 10            Charlotte/Douglas International Airport  CLT
# 11                        Miami International Airport  MIA
# 12                      Orlando International Airport  MCO
# 13               Newark Liberty International Airport  EWR
# 14          Detroit Metropolitan Wayne County Airport  DTW
# 15  Minneapolis-St. Paul International Airport/Wol...  MSP
# 16               Seattle-Tacoma International Airport  SEA
# 17                 Philadelphia International Airport  PHL
# 18                        Logan International Airport  BOS
# 19                                  LaGuardia Airport  LGA
# 20            Washington Dulles International Airport  IAD
# 21  Baltimore-Washington International Thurgood Ma...  BWI
# 22    Fort Lauderdale/Hollywood International Airport  FLL
# 23               Salt Lake City International Airport  SLC
# 24                     Honolulu International Airport  HNL
# 25                        Washington National Airport  DCA
# 26                       Midway International Airport  MDW
# 27                    San Diego International Airport  SAN
# 28                        Tampa International Airport  TPA
# 29                     Portland International Airport  PDX
# 30            Lambert-St. Louis International Airport  STL
# 31                  Kansas City International Airport  MCI
# 32                      Memphis International Airport  MEM
# 33             General Mitchell International Airport  MKE
# 34         Metropolitan Oakland International Airport  OAK
# 35            Cleveland-Hopkins International Airport  CLE
# 36               Raleigh-Durham International Airport  RDU
# 37                    Nashville International Airport  BNA
# 38                   Sacramento International Airport  SMF
# 39                           William P. Hobby Airport  HOU
# 40                   John Wayne Airport-Orange County  SNA
# 41             Luis Muñoz Marín International Airport  SJU
# 42             Austin-Bergstrom International Airport  AUS
# 43  Louis Armstrong New Orleans International Airport  MSY
# 44                     San Jose International Airport  SJC
# 45                   Pittsburgh International Airport  PIT
# 46                  San Antonio International Airport  SAT
# 47  Cincinnati/Northern Kentucky International Air...  CVG
# 48                                  Dallas Love Field  DAL
# 49                 Indianapolis International Airport  IND
#
#                           City State
# 0                      Atlanta    GA
# 1                      Chicago    IL
# 2                  Los Angeles    CA
# 3            Dallas/Fort Worth    TX
# 4                       Denver    CO
# 5                     New York    NY
# 6                      Houston    TX
# 7                San Francisco    CA
# 8                    Las Vegas    NV
# 9                      Phoenix    AZ
# 10                   Charlotte    NC
# 11                       Miami    FL
# 12                     Orlando    FL
# 13             Newark/New York    NJ
# 14                     Detroit    MI
# 15         Minneapolis/St Paul    MN
# 16                     Seattle    WA
# 17                Philadelphia    PA
# 18                      Boston    MA
# 19                    New York    NY
# 20              Washington, DC    VA
# 21  Baltimore/Washington, D.C.    MD
# 22             Fort Lauderdale    FL
# 23              Salt Lake City    UT
# 24                    Honolulu    HI
# 25            Washington, D.C.    VA
# 26                     Chicago    IL
# 27                   San Diego    CA
# 28                       Tampa    FL
# 29                    Portland    OR
# 30                   St. Louis    MO
# 31                 Kansas City    MO
# 32                     Memphis    TN
# 33                   Milwaukee    WI
# 34                     Oakland    CA
# 35                   Cleveland    OH
# 36                     Raleigh    NC
# 37                   Nashville    TN
# 38                  Sacramento    CA
# 39                     Houston    TX
# 40               Orange County    CA
# 41                    San Juan    PR
# 42                      Austin    TX
# 43                 New Orleans    LA
# 44                    San Jose    CA
# 45                  Pittsburgh    PA
# 46                 San Antonio    TX
# 47                  Cincinnati    KY
# 48                      Dallas    TX
# 49                Indianapolis    IN

# %%
airports=list(busyairportdf["Code"])

prices=[]
origins=[]
destinations=[]
distances=[]
departs=[]
purchases=[]
classes=[]
gates=[]


for origin in airports:
    print(f"Searching flights out of {origin}")
    prices_url=f"http://api.travelpayouts.com/v2/prices/latest?currency=usd&limit=1000&origin={origin}&one_way=true"
    headers = {"X-Access-Token": "f2b1a8fac25474496ea091529cddd0ec",
             }
    prices_data = requests.get(prices_url, headers=headers).json()

    for i in prices_data["data"]:
        destination=i["destination"]
        depart=i["depart_date"]
        print(f"From {origin} to {destination}.")
        prices.append(i["value"])
        origins.append(origin)
        destinations.append(destination)
        distances.append(int(int(i["distance"])//1.609)) #convert km to miles
        departs.append(depart)
        purchases.append(i["found_at"])
        classes.append(i["trip_class"])
        gates.append(i["gate"])

# Store data into dataframe 
prices_df=pd.DataFrame({"Origin":origins,
                        "Destination":destinations,
                        "Purchase Time":purchases,
                        "Distance (Miles)":distances,
                        "Departure Date":departs,
                        "Price (USD)":prices,
                        "Class":classes,
                        "Purchase Gate":gates
                       })
# Out:
# Searching flights out of ATL
# From ATL to ORL.
# From ATL to MIA.
# From ATL to PHL.
# From ATL to DFW.
# From ATL to MSY.
# From ATL to FLL.
# From ATL to CHI.
# From ATL to BWI.
# From ATL to HOU.
# From ATL to BNA.
# From ATL to NYC.
# From ATL to LAS.
# From ATL to WAS.
# From ATL to SAT.
# From ATL to TPA.
# From ATL to SEA.
# From ATL to PIT.
# From ATL to LAX.
# From ATL to JAX.
# From ATL to OAK.
# From ATL to MKC.
# From ATL to GUA.
# From ATL to ISP.
# From ATL to OKC.
# From ATL to DTT.
# From ATL to OMA.
# From ATL to MLB.
# From ATL to STI.
# From ATL to FSD.
# From ATL to SDQ.
# From ATL to MBJ.
# From ATL to PDX.
# From ATL to AVP.
# From ATL to JAC.
# From ATL to SFO.
# From ATL to DUJ.
# From ATL to LNS.
# From ATL to FKL.
# From ATL to PTY.
# From ATL to HGR.
# From ATL to GDL.
# From ATL to MGW.
# From ATL to AOO.
# From ATL to BFD.
# From ATL to SUX.
# From ATL to AMA.
# From ATL to MEM.
# From ATL to JAN.
# From ATL to HAR.
# From ATL to MEX.
# From ATL to CVG.
# From ATL to BJX.
# From ATL to LON.
# From ATL to FNT.
# From ATL to QRO.
# From ATL to RDU.
# From ATL to CMH.
# From ATL to ANC.
# From ATL to HNL.
# From ATL to LIM.
# From ATL to ATH.
# From ATL to PSC.
# From ATL to DEL.
# From ATL to CEK.
# From ATL to BOM.
# From ATL to SGF.
# From ATL to HRO.
# From ATL to SLU.
# From ATL to BSB.
# From ATL to ABV.
# From ATL to TYO.
# From ATL to IEV.
# From ATL to PMW.
# From ATL to EBB.
# From ATL to VIE.
# Searching flights out of ORD
# From ORD to HOU.
# From ORD to BOS.
# From ORD to ORL.
# From ORD to FLL.
# From ORD to NYC.
# From ORD to LAS.
# From ORD to BWI.
# From ORD to SFO.
# From ORD to PHL.
# From ORD to CMH.
# From ORD to DFW.
# From ORD to LAX.
# From ORD to OAK.
# From ORD to MIA.
# From ORD to MEX.
# From ORD to DEN.
# From ORD to ISP.
# From ORD to BUF.
# From ORD to ATL.
# From ORD to MSY.
# From ORD to PBI.
# From ORD to SAN.
# From ORD to SEA.
# From ORD to MSP.
# From ORD to MLB.
# From ORD to SDF.
# From ORD to ABQ.
# From ORD to RDU.
# From ORD to CLE.
# From ORD to SNA.
# From ORD to SJU.
# From ORD to AUS.
# From ORD to YTO.
# From ORD to PDX.
# From ORD to CLT.
# From ORD to BNA.
# From ORD to WAS.
# From ORD to JAN.
# From ORD to PHX.
# From ORD to STI.
# From ORD to SJC.
# From ORD to YMQ.
# From ORD to GSO.
# From ORD to CJS.
# From ORD to YVR.
# From ORD to LON.
# From ORD to GDL.
# From ORD to YHZ.
# From ORD to PAR.
# From ORD to SAC.
# From ORD to BCN.
# From ORD to DTT.
# From ORD to FMY.
# From ORD to BJX.
# From ORD to PWM.
# From ORD to PUJ.
# From ORD to AMS.
# From ORD to GUA.
# From ORD to MTY.
# From ORD to CTA.
# From ORD to PIT.
# From ORD to HNL.
# From ORD to ROM.
# From ORD to ZRH.
# From ORD to MUC.
# From ORD to BEG.
# From ORD to FKL.
# From ORD to MLM.
# From ORD to GRX.
# From ORD to IEV.
# From ORD to MAN.
# From ORD to JST.
# From ORD to AUA.
# From ORD to DUJ.
# From ORD to MGW.
# From ORD to AOO.
# From ORD to HGR.
# From ORD to BFD.
# From ORD to QRO.
# From ORD to IST.
# From ORD to SKG.
# From ORD to ANC.
# From ORD to MSQ.
# From ORD to LNS.
# From ORD to LED.
# From ORD to VER.
# From ORD to CAI.
# From ORD to HAR.
# From ORD to SYR.
# From ORD to KHI.
# From ORD to RIC.
# From ORD to ATQ.
# From ORD to MCX.
# From ORD to CAN.
# From ORD to DEL.
# From ORD to SIN.
# From ORD to MLA.
# From ORD to KTM.
# From ORD to MNL.
# From ORD to MOW.
# From ORD to BOM.
# From ORD to PNQ.
# From ORD to SCL.
# From ORD to DXB.
# From ORD to KWI.
# From ORD to CEB.
# From ORD to PRG.
# From ORD to USM.
# From ORD to TYO.
# From ORD to DPS.
# From ORD to TAS.
# From ORD to LFW.
# From ORD to KIV.
# From ORD to WNP.
# From ORD to SEL.
# From ORD to NAG.
# From ORD to LEN.
# Searching flights out of LAX
# From LAX to LAS.
# From LAX to SFO.
# From LAX to HOU.
# From LAX to OAK.
# From LAX to PHX.
# From LAX to SJC.
# From LAX to DFW.
# From LAX to PIT.
# From LAX to CHI.
# From LAX to PDX.
# From LAX to GDL.
# From LAX to MSP.
# From LAX to BWI.
# From LAX to SEA.
# From LAX to ORL.
# From LAX to MKC.
# From LAX to DEN.
# From LAX to BOI.
# From LAX to SAN.
# From LAX to ELP.
# From LAX to SLC.
# From LAX to PHL.
# From LAX to GEG.
# From LAX to AUS.
# From LAX to MEX.
# From LAX to DTT.
# From LAX to YVR.
# From LAX to STL.
# From LAX to SAT.
# From LAX to ATL.
# From LAX to SJD.
# From LAX to NYC.
# From LAX to BOS.
# From LAX to GUA.
# From LAX to CUN.
# From LAX to RDM.
# From LAX to ABQ.
# From LAX to FLL.
# From LAX to CMH.
# From LAX to OGG.
# From LAX to HNL.
# From LAX to GRR.
# From LAX to SAP.
# From LAX to PVD.
# From LAX to WAS.
# From LAX to PVR.
# From LAX to SJO.
# From LAX to BJX.
# From LAX to MMH.
# From LAX to MID.
# From LAX to TIJ.
# From LAX to MIA.
# From LAX to AGU.
# From LAX to TUS.
# From LAX to SDF.
# From LAX to ORF.
# From LAX to PIA.
# From LAX to PAR.
# From LAX to RDU.
# From LAX to REK.
# From LAX to MBS.
# From LAX to FSD.
# From LAX to PUJ.
# From LAX to ISP.
# From LAX to DAB.
# From LAX to IND.
# From LAX to TAP.
# From LAX to HRL.
# From LAX to DAY.
# From LAX to SPI.
# From LAX to MBJ.
# From LAX to LIM.
# From LAX to QRO.
# From LAX to MGA.
# From LAX to BNA.
# From LAX to LON.
# From LAX to MLM.
# From LAX to SJU.
# From LAX to TPE.
# From LAX to BUF.
# From LAX to MOW.
# From LAX to SGN.
# From LAX to MEM.
# From LAX to FMY.
# From LAX to BCN.
# From LAX to CAN.
# From LAX to SEL.
# From LAX to LED.
# From LAX to LIS.
# From LAX to TYO.
# From LAX to JAN.
# From LAX to IST.
# From LAX to IEV.
# From LAX to ROM.
# From LAX to TLV.
# From LAX to PTP.
# From LAX to MNL.
# From LAX to KWL.
# From LAX to MUC.
# From LAX to CTU.
# From LAX to AVP.
# From LAX to BKK.
# From LAX to RAK.
# From LAX to FRA.
# From LAX to LPB.
# From LAX to AMS.
# From LAX to SIN.
# From LAX to DUS.
# From LAX to AGP.
# From LAX to MAD.
# From LAX to HAR.
# From LAX to EVN.
# From LAX to BUD.
# From LAX to ITO.
# From LAX to CAI.
# From LAX to PHS.
# From LAX to AER.
# From LAX to BJS.
# From LAX to LNS.
# From LAX to DPS.
# From LAX to BEY.
# From LAX to DUJ.
# From LAX to FKL.
# From LAX to AOO.
# From LAX to SCU.
# From LAX to DEL.
# From LAX to BFD.
# From LAX to ODS.
# From LAX to SYD.
# From LAX to ALA.
# From LAX to BOM.
# From LAX to DOH.
# From LAX to MGW.
# From LAX to CAS.
# From LAX to KTM.
# From LAX to WNP.
# From LAX to CCS.
# From LAX to HGR.
# From LAX to MEL.
# From LAX to SAL.
# From LAX to JNB.
# From LAX to KUF.
# From LAX to TBS.
# From LAX to THR.
# From LAX to PER.
# From LAX to AKL.
# From LAX to AMD.
# From LAX to TJM.
# From LAX to KBL.
# From LAX to CPT.
# From LAX to SAO.
# From LAX to VVO.
# From LAX to MAO.
# From LAX to NAN.
# From LAX to BOB.
# Searching flights out of DFW
# From DFW to ATL.
# From DFW to HRO.
# From DFW to ELD.
# From DFW to HOT.
# From DFW to DEN.
# From DFW to LAS.
# From DFW to LAX.
# From DFW to TPA.
# From DFW to ORL.
# From DFW to MIA.
# From DFW to FLL.
# From DFW to DTT.
# From DFW to BWI.
# From DFW to NYC.
# From DFW to MEM.
# From DFW to BOS.
# From DFW to HOU.
# From DFW to MKC.
# From DFW to MSP.
# From DFW to ISP.
# From DFW to MEX.
# From DFW to SAN.
# From DFW to WAS.
# From DFW to SLC.
# From DFW to PIT.
# From DFW to JAN.
# From DFW to SJC.
# From DFW to LIT.
# From DFW to CHI.
# From DFW to AVP.
# From DFW to BNA.
# From DFW to GDL.
# From DFW to BKG.
# From DFW to MKL.
# From DFW to CLT.
# From DFW to JAX.
# From DFW to BHM.
# From DFW to MGW.
# From DFW to BJX.
# From DFW to COS.
# From DFW to RIC.
# From DFW to BQN.
# From DFW to DSM.
# From DFW to NAS.
# From DFW to BFD.
# From DFW to JST.
# From DFW to PFN.
# From DFW to TUS.
# From DFW to LNS.
# From DFW to BDL.
# From DFW to STL.
# From DFW to SJU.
# From DFW to GSP.
# From DFW to LAN.
# From DFW to GYE.
# From DFW to YWG.
# From DFW to MSY.
# From DFW to CMH.
# From DFW to MKE.
# From DFW to FKL.
# From DFW to HGR.
# From DFW to SYR.
# From DFW to AOO.
# From DFW to DUJ.
# From DFW to MLM.
# From DFW to HAR.
# From DFW to LON.
# From DFW to PHX.
# From DFW to LIM.
# From DFW to MTY.
# From DFW to FAY.
# From DFW to MFR.
# From DFW to FYV.
# From DFW to GUA.
# From DFW to VPS.
# From DFW to CHA.
# From DFW to HNL.
# From DFW to MAD.
# From DFW to BJS.
# From DFW to GJT.
# From DFW to BKK.
# From DFW to SGN.
# From DFW to MOW.
# From DFW to BEY.
# From DFW to BCN.
# From DFW to KTM.
# From DFW to HRB.
# From DFW to NBO.
# From DFW to HYD.
# From DFW to DEL.
# From DFW to SYX.
# From DFW to CJU.
# From DFW to WLG.
# From DFW to BGW.
# From DFW to KGL.
# Searching flights out of DEN
# From DEN to LAS.
# From DEN to TUS.
# From DEN to DFW.
# From DEN to FLL.
# From DEN to BWI.
# From DEN to WAS.
# From DEN to ORL.
# From DEN to NYC.
# From DEN to PIT.
# From DEN to STL.
# From DEN to OMA.
# From DEN to SFO.
# From DEN to ELP.
# From DEN to CHS.
# From DEN to MSY.
# From DEN to PHX.
# From DEN to SAN.
# From DEN to ATL.
# From DEN to MSP.
# From DEN to LAX.
# From DEN to PHL.
# From DEN to OAK.
# From DEN to CMH.
# From DEN to AUS.
# From DEN to ICT.
# From DEN to MAF.
# From DEN to HAR.
# From DEN to RDU.
# From DEN to BNA.
# From DEN to YMQ.
# From DEN to TPA.
# From DEN to CLE.
# From DEN to YYC.
# From DEN to SJC.
# From DEN to SNA.
# From DEN to ABQ.
# From DEN to LON.
# From DEN to SEA.
# From DEN to AGS.
# From DEN to MEM.
# From DEN to SJU.
# From DEN to HNL.
# From DEN to VIE.
# From DEN to LBB.
# From DEN to OGG.
# From DEN to MOW.
# From DEN to AMS.
# From DEN to TYS.
# From DEN to FRA.
# From DEN to SUX.
# From DEN to ZCL.
# From DEN to SHA.
# From DEN to PPT.
# From DEN to ISP.
# From DEN to MSQ.
# From DEN to DPL.
# Searching flights out of JFK
# From JFK to WAS.
# From JFK to BUF.
# From JFK to BOS.
# From JFK to BWI.
# From JFK to CHI.
# From JFK to YMQ.
# From JFK to DFW.
# From JFK to MIA.
# From JFK to ORL.
# From JFK to FLL.
# From JFK to ATL.
# From JFK to PIT.
# From JFK to YTO.
# From JFK to CAE.
# From JFK to DTT.
# From JFK to LEX.
# From JFK to LAS.
# From JFK to MEX.
# From JFK to CMH.
# From JFK to PWM.
# From JFK to CLT.
# From JFK to SJU.
# From JFK to HGR.
# From JFK to GCM.
# From JFK to SFO.
# From JFK to DUJ.
# From JFK to MGW.
# From JFK to LNS.
# From JFK to AOO.
# From JFK to JAX.
# From JFK to YVR.
# From JFK to DEN.
# From JFK to LAX.
# From JFK to BQN.
# From JFK to LIT.
# From JFK to PHL.
# From JFK to PBI.
# From JFK to SAC.
# From JFK to DAY.
# From JFK to SRQ.
# From JFK to SEA.
# From JFK to MSY.
# From JFK to CVG.
# From JFK to NAS.
# From JFK to PDX.
# From JFK to ONT.
# From JFK to HAV.
# From JFK to OAK.
# From JFK to HOU.
# From JFK to STT.
# From JFK to SDQ.
# From JFK to CUN.
# From JFK to STI.
# From JFK to JST.
# From JFK to PAP.
# From JFK to RDU.
# From JFK to LON.
# From JFK to MBJ.
# From JFK to EYW.
# From JFK to POS.
# From JFK to PHX.
# From JFK to PTY.
# From JFK to AUS.
# From JFK to SAN.
# From JFK to PUJ.
# From JFK to AVP.
# From JFK to MDE.
# From JFK to AUA.
# From JFK to ROM.
# From JFK to BGI.
# From JFK to TPA.
# From JFK to PAR.
# From JFK to SJC.
# From JFK to SAP.
# From JFK to WAW.
# From JFK to DUB.
# From JFK to CYB.
# From JFK to IND.
# From JFK to AGP.
# From JFK to VNO.
# From JFK to SAL.
# From JFK to NCE.
# From JFK to ANC.
# From JFK to JNU.
# From JFK to LIS.
# From JFK to SJO.
# From JFK to REK.
# From JFK to ATW.
# From JFK to BCN.
# From JFK to MAD.
# From JFK to ATH.
# From JFK to KUT.
# From JFK to BER.
# From JFK to MIL.
# From JFK to RIX.
# From JFK to TLV.
# From JFK to HEL.
# From JFK to UIO.
# From JFK to MOW.
# From JFK to HAR.
# From JFK to BHX.
# From JFK to ILM.
# From JFK to IST.
# From JFK to AXM.
# From JFK to IEV.
# From JFK to FRA.
# From JFK to LED.
# From JFK to YQB.
# From JFK to BRU.
# From JFK to CTG.
# From JFK to STR.
# From JFK to VCE.
# From JFK to BFD.
# From JFK to JMK.
# From JFK to BUR.
# From JFK to MSQ.
# From JFK to ALG.
# From JFK to LGB.
# From JFK to GUA.
# From JFK to STO.
# From JFK to IAG.
# From JFK to FKL.
# From JFK to SBY.
# From JFK to VIE.
# From JFK to CLO.
# From JFK to JTR.
# From JFK to GVA.
# From JFK to POP.
# From JFK to ORN.
# From JFK to AMM.
# From JFK to HRL.
# From JFK to LAN.
# From JFK to TBS.
# From JFK to VRA.
# From JFK to CAI.
# From JFK to MUC.
# From JFK to OSL.
# From JFK to LAR.
# From JFK to STL.
# From JFK to SMA.
# From JFK to KZN.
# From JFK to ROA.
# From JFK to LPB.
# From JFK to EVN.
# From JFK to MCX.
# From JFK to CEK.
# From JFK to HNL.
# From JFK to SIP.
# From JFK to ISB.
# From JFK to DEL.
# From JFK to MFE.
# From JFK to ABJ.
# From JFK to AYT.
# From JFK to AUH.
# From JFK to SUF.
# From JFK to BJS.
# From JFK to BEG.
# From JFK to ALA.
# From JFK to KIV.
# From JFK to KJA.
# From JFK to TAS.
# From JFK to OVB.
# From JFK to FRU.
# From JFK to BRO.
# From JFK to DXB.
# From JFK to LHE.
# From JFK to CAS.
# From JFK to CAN.
# From JFK to TUN.
# From JFK to CTU.
# From JFK to ROV.
# From JFK to SHA.
# From JFK to ACC.
# From JFK to KEJ.
# From JFK to KZR.
# From JFK to KGD.
# From JFK to DPS.
# From JFK to BOM.
# From JFK to BAH.
# From JFK to SGN.
# From JFK to SEL.
# From JFK to KUL.
# From JFK to NGO.
# From JFK to VVO.
# From JFK to JAI.
# From JFK to AMD.
# From JFK to KIN.
# From JFK to HKG.
# From JFK to BLR.
# From JFK to BUS.
# From JFK to DYU.
# From JFK to KTM.
# From JFK to NKC.
# From JFK to IKT.
# From JFK to KHI.
# From JFK to TYO.
# From JFK to UUS.
# From JFK to BAK.
# From JFK to LOS.
# From JFK to SYD.
# From JFK to BUE.
# From JFK to SVD.
# From JFK to OUA.
# From JFK to MLW.
# From JFK to SAO.
# From JFK to SSA.
# From JFK to MED.
# From JFK to BPN.
# From JFK to BEY.
# From JFK to TGD.
# From JFK to RIO.
# From JFK to SKD.
# From JFK to KZO.
# From JFK to HNY.
# From JFK to CPT.
# From JFK to MAA.
# From JFK to NKG.
# From JFK to BKO.
# From JFK to MEL.
# From JFK to GUM.
# From JFK to FOC.
# From JFK to HRE.
# From JFK to MNL.
# From JFK to ASB.
# Searching flights out of IAH
# From IAH to DEN.
# From IAH to LAS.
# From IAH to LAX.
# From IAH to ORL.
# From IAH to MIA.
# From IAH to FLL.
# From IAH to NYC.
# From IAH to OAK.
# From IAH to CUN.
# From IAH to DFW.
# From IAH to JAX.
# From IAH to BWI.
# From IAH to SAL.
# From IAH to PIT.
# From IAH to GEG.
# From IAH to PHL.
# From IAH to SAN.
# From IAH to PDX.
# From IAH to MSY.
# From IAH to MEM.
# From IAH to CHI.
# From IAH to GDL.
# From IAH to SLC.
# From IAH to EAT.
# From IAH to PVR.
# From IAH to DTT.
# From IAH to ABQ.
# From IAH to MEX.
# From IAH to EYW.
# From IAH to MBJ.
# From IAH to WAS.
# From IAH to GPT.
# From IAH to IND.
# From IAH to ROC.
# From IAH to HAV.
# From IAH to POS.
# From IAH to SJC.
# From IAH to JST.
# From IAH to DUJ.
# From IAH to MGW.
# From IAH to HGR.
# From IAH to AOO.
# From IAH to BHM.
# From IAH to BTR.
# From IAH to LON.
# From IAH to LNS.
# From IAH to CMW.
# From IAH to ELP.
# From IAH to ISP.
# From IAH to HSV.
# From IAH to SDQ.
# From IAH to CEB.
# From IAH to BFS.
# From IAH to PRG.
# From IAH to BHX.
# From IAH to GLA.
# From IAH to ORK.
# From IAH to SYD.
# From IAH to HYD.
# From IAH to BLR.
# From IAH to CMB.
# From IAH to ADD.
# From IAH to SZG.
# From IAH to MAD.
# From IAH to SSH.
# From IAH to EVN.
# From IAH to CEK.
# From IAH to PMO.
# Searching flights out of SFO
# From SFO to LAS.
# From SFO to LAX.
# From SFO to SAN.
# From SFO to SEA.
# From SFO to PHX.
# From SFO to PSP.
# From SFO to OAK.
# From SFO to YYC.
# From SFO to NYC.
# From SFO to CHI.
# From SFO to LGB.
# From SFO to GDL.
# From SFO to STL.
# From SFO to FLL.
# From SFO to CMH.
# From SFO to MIA.
# From SFO to BOS.
# From SFO to CLE.
# From SFO to PHL.
# From SFO to YTO.
# From SFO to OMA.
# From SFO to ABQ.
# From SFO to ATL.
# From SFO to MEX.
# From SFO to BDL.
# From SFO to MTY.
# From SFO to SNA.
# From SFO to VER.
# From SFO to DFW.
# From SFO to OAX.
# From SFO to FRA.
# From SFO to LON.
# From SFO to MSY.
# From SFO to IND.
# From SFO to WAS.
# From SFO to HNL.
# From SFO to MID.
# From SFO to BKK.
# From SFO to MSP.
# From SFO to SGN.
# From SFO to BER.
# From SFO to GSO.
# From SFO to SDQ.
# From SFO to CTU.
# From SFO to MBJ.
# From SFO to PIT.
# From SFO to PAR.
# From SFO to HKT.
# From SFO to NKG.
# From SFO to BJS.
# From SFO to CAN.
# From SFO to SHA.
# From SFO to TYS.
# From SFO to DEL.
# From SFO to BUF.
# From SFO to SIA.
# From SFO to MOW.
# From SFO to IEV.
# From SFO to EYW.
# From SFO to CGN.
# From SFO to DAC.
# From SFO to ISP.
# From SFO to MLM.
# From SFO to AMS.
# From SFO to PPT.
# From SFO to BOG.
# From SFO to JAC.
# From SFO to TRV.
# From SFO to ZRH.
# From SFO to MNL.
# From SFO to TYO.
# From SFO to KUL.
# From SFO to BEG.
# From SFO to SCL.
# From SFO to BCN.
# From SFO to CAI.
# From SFO to LIM.
# From SFO to TLV.
# From SFO to SIN.
# From SFO to BUE.
# From SFO to SAO.
# From SFO to BOM.
# From SFO to CJB.
# From SFO to DXB.
# From SFO to GGT.
# From SFO to MEL.
# From SFO to DUS.
# From SFO to ISB.
# From SFO to REC.
# From SFO to NAT.
# From SFO to KHV.
# From SFO to ANK.
# From SFO to HEL.
# From SFO to WLG.
# From SFO to JPA.
# From SFO to LED.
# From SFO to AKL.
# From SFO to ZQN.
# From SFO to JMK.
# From SFO to MUX.
# From SFO to BLR.
# From SFO to GOI.
# From SFO to HYD.
# Searching flights out of LAS
# From LAS to LAX.
# From LAS to DEN.
# From LAS to OAK.
# From LAS to SFO.
# From LAS to HOU.
# From LAS to SAN.
# From LAS to STL.
# From LAS to DFW.
# From LAS to RNO.
# From LAS to CHI.
# From LAS to SAT.
# From LAS to ABQ.
# From LAS to SAC.
# From LAS to SLC.
# From LAS to MEX.
# From LAS to PIT.
# From LAS to BWI.
# From LAS to TPA.
# From LAS to IND.
# From LAS to NYC.
# From LAS to MKC.
# From LAS to TUL.
# From LAS to DTT.
# From LAS to PHL.
# From LAS to ELP.
# From LAS to FLL.
# From LAS to MIA.
# From LAS to PVR.
# From LAS to CMH.
# From LAS to BNA.
# From LAS to VSA.
# From LAS to MEM.
# From LAS to SJO.
# From LAS to RDD.
# From LAS to WAS.
# From LAS to BUF.
# From LAS to SHV.
# From LAS to ATL.
# From LAS to ISP.
# From LAS to YTO.
# From LAS to JAX.
# From LAS to ASE.
# From LAS to SGF.
# From LAS to MSY.
# From LAS to GRR.
# From LAS to BUR.
# From LAS to CLE.
# From LAS to HNL.
# From LAS to JAN.
# From LAS to PAR.
# From LAS to BKK.
# From LAS to IST.
# From LAS to LON.
# From LAS to IEV.
# From LAS to NCE.
# From LAS to SDQ.
# From LAS to SSM.
# From LAS to FOC.
# From LAS to TLV.
# From LAS to AYT.
# From LAS to MOW.
# From LAS to DUS.
# From LAS to MAD.
# From LAS to AKL.
# From LAS to BOM.
# From LAS to THR.
# From LAS to AMD.
# From LAS to SAO.
# From LAS to LED.
# Searching flights out of PHX
# From PHX to LAX.
# From PHX to MLI.
# From PHX to FLL.
# From PHX to LAS.
# From PHX to ABQ.
# From PHX to DSM.
# From PHX to DEN.
# From PHX to MSP.
# From PHX to YTO.
# From PHX to ATL.
# From PHX to SAN.
# From PHX to AUS.
# From PHX to CHI.
# From PHX to HOU.
# From PHX to ONT.
# From PHX to OMA.
# From PHX to GDL.
# From PHX to ORL.
# From PHX to YVR.
# From PHX to DTT.
# From PHX to MIA.
# From PHX to NYC.
# From PHX to PIT.
# From PHX to MKC.
# From PHX to WAS.
# From PHX to MKE.
# From PHX to SEA.
# From PHX to BWI.
# From PHX to SJC.
# From PHX to CAE.
# From PHX to SAC.
# From PHX to CZM.
# From PHX to ISP.
# From PHX to BTV.
# From PHX to TRI.
# From PHX to PUJ.
# From PHX to LON.
# From PHX to PVR.
# From PHX to MNL.
# From PHX to DUB.
# From PHX to SKB.
# From PHX to GFK.
# From PHX to OKA.
# Searching flights out of CLT
# From CLT to AUS.
# From CLT to CVG.
# From CLT to WAS.
# From CLT to BWI.
# From CLT to CLE.
# From CLT to NYC.
# From CLT to PIT.
# From CLT to CHI.
# From CLT to ORL.
# From CLT to PDX.
# From CLT to LNS.
# From CLT to HOU.
# From CLT to LAS.
# From CLT to JST.
# From CLT to HGR.
# From CLT to TPA.
# From CLT to MBJ.
# From CLT to FLL.
# From CLT to DUJ.
# From CLT to MGW.
# From CLT to FKL.
# From CLT to BFD.
# From CLT to AOO.
# From CLT to PHX.
# From CLT to ICT.
# From CLT to AVL.
# From CLT to AVP.
# From CLT to SJO.
# From CLT to ISP.
# From CLT to PBI.
# From CLT to HAR.
# From CLT to MGA.
# From CLT to CUN.
# From CLT to CSL.
# From CLT to SEA.
# From CLT to TSE.
# From CLT to CAI.
# From CLT to AMD.
# From CLT to CCU.
# Searching flights out of MIA
# From MIA to ATL.
# From MIA to BDL.
# From MIA to BOS.
# From MIA to NYC.
# From MIA to MSY.
# From MIA to HOU.
# From MIA to CHI.
# From MIA to RDU.
# From MIA to TPA.
# From MIA to NAS.
# From MIA to SJU.
# From MIA to MEX.
# From MIA to PTY.
# From MIA to ORL.
# From MIA to WAS.
# From MIA to PAP.
# From MIA to AUS.
# From MIA to DFW.
# From MIA to EYW.
# From MIA to GCM.
# From MIA to MEM.
# From MIA to HAV.
# From MIA to RIO.
# From MIA to LIT.
# From MIA to LAX.
# From MIA to YMQ.
# From MIA to SAN.
# From MIA to PIT.
# From MIA to SFO.
# From MIA to VRA.
# From MIA to ILM.
# From MIA to PVD.
# From MIA to SDQ.
# From MIA to CCS.
# From MIA to LAS.
# From MIA to MTY.
# From MIA to BWI.
# From MIA to PUJ.
# From MIA to AVL.
# From MIA to SXM.
# From MIA to SLC.
# From MIA to UIO.
# From MIA to CLE.
# From MIA to OAK.
# From MIA to SEA.
# From MIA to PVR.
# From MIA to CLO.
# From MIA to BOG.
# From MIA to LIS.
# From MIA to MUC.
# From MIA to MAD.
# From MIA to HMO.
# From MIA to LON.
# From MIA to PEI.
# From MIA to BLA.
# From MIA to PAR.
# From MIA to BRU.
# From MIA to VLC.
# From MIA to OSL.
# From MIA to GUA.
# From MIA to BCN.
# From MIA to ATH.
# From MIA to BER.
# From MIA to TXK.
# From MIA to MOW.
# From MIA to LPA.
# From MIA to IST.
# From MIA to ROM.
# From MIA to SAP.
# From MIA to LED.
# From MIA to ABJ.
# From MIA to AMS.
# From MIA to NAP.
# From MIA to YTO.
# From MIA to CEK.
# From MIA to KRR.
# From MIA to SIP.
# From MIA to MSQ.
# From MIA to REK.
# From MIA to DUB.
# From MIA to ACC.
# From MIA to BUH.
# From MIA to KGF.
# From MIA to SVX.
# From MIA to GVA.
# From MIA to SAO.
# From MIA to SCL.
# From MIA to JER.
# From MIA to SSA.
# From MIA to DXB.
# From MIA to PDX.
# From MIA to SHE.
# From MIA to ODS.
# From MIA to SOF.
# From MIA to BUE.
# From MIA to POA.
# From MIA to DPS.
# Searching flights out of MCO
# From MCO to PIT.
# From MCO to MSY.
# From MCO to BNA.
# From MCO to CHI.
# From MCO to FLL.
# From MCO to HOU.
# From MCO to CAK.
# From MCO to NYC.
# From MCO to BWI.
# From MCO to PHL.
# From MCO to ONT.
# From MCO to WAS.
# From MCO to DFW.
# From MCO to HAR.
# From MCO to DUJ.
# From MCO to DEN.
# From MCO to LAX.
# From MCO to SJU.
# From MCO to BQN.
# From MCO to MIA.
# From MCO to BOS.
# From MCO to RIC.
# From MCO to MKE.
# From MCO to LAS.
# From MCO to MEM.
# From MCO to ATL.
# From MCO to MEX.
# From MCO to GUA.
# From MCO to SLC.
# From MCO to ISP.
# From MCO to COS.
# From MCO to PNS.
# From MCO to ROC.
# From MCO to FOR.
# From MCO to CLE.
# From MCO to BDL.
# From MCO to MKG.
# From MCO to SFO.
# From MCO to FKL.
# From MCO to HGR.
# From MCO to ABQ.
# From MCO to YMQ.
# From MCO to AOO.
# From MCO to MGW.
# From MCO to LNS.
# From MCO to AUS.
# From MCO to OAK.
# From MCO to BFD.
# From MCO to MTY.
# From MCO to PSE.
# From MCO to SAT.
# From MCO to PVD.
# From MCO to SAN.
# From MCO to PHX.
# From MCO to HOB.
# From MCO to SJO.
# From MCO to PAR.
# From MCO to LON.
# From MCO to STX.
# From MCO to TYS.
# From MCO to SOU.
# From MCO to FRA.
# From MCO to EVV.
# From MCO to BER.
# From MCO to STI.
# From MCO to ROM.
# From MCO to ANU.
# From MCO to MAN.
# From MCO to ANC.
# From MCO to LRD.
# From MCO to MOW.
# From MCO to RIO.
# From MCO to TUN.
# From MCO to BOM.
# From MCO to HKG.
# From MCO to DPS.
# From MCO to MAA.
# From MCO to CAS.
# Searching flights out of EWR
# From EWR to CVG.
# From EWR to MIA.
# From EWR to FLL.
# From EWR to ORL.
# From EWR to ATL.
# From EWR to BUF.
# From EWR to BOS.
# From EWR to YTO.
# From EWR to WAS.
# From EWR to CLT.
# From EWR to CHI.
# From EWR to CMH.
# From EWR to LEX.
# From EWR to MSY.
# From EWR to JAX.
# From EWR to PIT.
# From EWR to DTT.
# From EWR to ILM.
# From EWR to YMQ.
# From EWR to LAS.
# From EWR to CAE.
# From EWR to HOU.
# From EWR to AUS.
# From EWR to BWI.
# From EWR to MEX.
# From EWR to PWM.
# From EWR to PTY.
# From EWR to LAX.
# From EWR to SDQ.
# From EWR to TPA.
# From EWR to SJU.
# From EWR to STI.
# From EWR to PBI.
# From EWR to SFO.
# From EWR to BQN.
# From EWR to ONT.
# From EWR to MDE.
# From EWR to DFW.
# From EWR to CUN.
# From EWR to DAY.
# From EWR to YVR.
# From EWR to OAK.
# From EWR to SJC.
# From EWR to SAL.
# From EWR to SJO.
# From EWR to PDX.
# From EWR to LAN.
# From EWR to NAS.
# From EWR to SAN.
# From EWR to SAP.
# From EWR to HAR.
# From EWR to RDU.
# From EWR to PAR.
# From EWR to ATW.
# From EWR to PAP.
# From EWR to MBJ.
# From EWR to LIT.
# From EWR to AXM.
# From EWR to LON.
# From EWR to YQB.
# From EWR to CTG.
# From EWR to POS.
# From EWR to SEA.
# From EWR to EYW.
# From EWR to PHL.
# From EWR to DEN.
# From EWR to SAC.
# From EWR to AVP.
# From EWR to IND.
# From EWR to PUJ.
# From EWR to LNS.
# From EWR to HAV.
# From EWR to PHX.
# From EWR to MAD.
# From EWR to NCE.
# From EWR to CLO.
# From EWR to GCM.
# From EWR to SRQ.
# From EWR to BRU.
# From EWR to DUB.
# From EWR to BCN.
# From EWR to ANC.
# From EWR to JNU.
# From EWR to LIS.
# From EWR to AUA.
# From EWR to VNO.
# From EWR to MOW.
# From EWR to REK.
# From EWR to HRL.
# From EWR to STT.
# From EWR to AGP.
# From EWR to WAW.
# From EWR to JTR.
# From EWR to ATH.
# From EWR to MIL.
# From EWR to TLV.
# From EWR to IAG.
# From EWR to FRA.
# From EWR to BGI.
# From EWR to BER.
# From EWR to IST.
# From EWR to VCE.
# From EWR to ALG.
# From EWR to BUR.
# From EWR to ROM.
# From EWR to RIX.
# From EWR to HGR.
# From EWR to LGB.
# From EWR to LED.
# From EWR to STR.
# From EWR to JMK.
# From EWR to GVA.
# From EWR to UIO.
# From EWR to STL.
# From EWR to CYB.
# From EWR to KUT.
# From EWR to ORN.
# From EWR to TBS.
# From EWR to AMM.
# From EWR to AYT.
# From EWR to BRO.
# From EWR to CAI.
# From EWR to VRA.
# From EWR to VIE.
# From EWR to STO.
# From EWR to GUA.
# From EWR to SBY.
# From EWR to BHX.
# From EWR to HEL.
# From EWR to ABJ.
# From EWR to MUC.
# From EWR to CAS.
# From EWR to MSQ.
# From EWR to ROA.
# From EWR to CEK.
# From EWR to LAR.
# From EWR to POP.
# From EWR to DEL.
# From EWR to MFE.
# From EWR to OSL.
# From EWR to HNL.
# From EWR to BJS.
# From EWR to KIN.
# From EWR to KJA.
# From EWR to EVN.
# From EWR to DXB.
# From EWR to CAN.
# From EWR to MCX.
# From EWR to LPB.
# From EWR to SIP.
# From EWR to SMA.
# From EWR to CTU.
# From EWR to SUF.
# From EWR to IEV.
# From EWR to OVB.
# From EWR to KEJ.
# From EWR to KTM.
# From EWR to KGD.
# From EWR to BOM.
# From EWR to HKG.
# From EWR to LOS.
# From EWR to BEG.
# From EWR to NKC.
# From EWR to SEL.
# From EWR to ALA.
# From EWR to KZR.
# From EWR to SGN.
# From EWR to ISB.
# From EWR to KIV.
# From EWR to TAS.
# From EWR to SHA.
# From EWR to ACC.
# From EWR to AUH.
# From EWR to TGD.
# From EWR to KZN.
# From EWR to AMD.
# From EWR to BUS.
# From EWR to TUN.
# From EWR to FRU.
# From EWR to KUL.
# From EWR to TYO.
# From EWR to KHI.
# From EWR to SSA.
# From EWR to ROV.
# From EWR to BLR.
# From EWR to RIO.
# From EWR to SYD.
# From EWR to LHE.
# From EWR to DPS.
# From EWR to SVD.
# From EWR to VVO.
# From EWR to UUS.
# From EWR to SAO.
# From EWR to BUE.
# From EWR to HRE.
# From EWR to BEY.
# From EWR to MED.
# From EWR to BAH.
# From EWR to DYU.
# From EWR to CPT.
# From EWR to OUA.
# From EWR to JAI.
# From EWR to BPN.
# From EWR to BAK.
# From EWR to SKD.
# From EWR to NGO.
# From EWR to HNY.
# From EWR to NKG.
# From EWR to IKT.
# From EWR to MAA.
# From EWR to GUM.
# From EWR to FOC.
# From EWR to MEL.
# From EWR to MLW.
# From EWR to BKO.
# From EWR to MNL.
# From EWR to KZO.
# From EWR to ASB.
# From EWR to JST.
# From EWR to AOO.
# Searching flights out of DTW
# From DTW to RDU.
# From DTW to FLL.
# From DTW to HOU.
# From DTW to ORL.
# From DTW to OAK.
# From DTW to CHI.
# From DTW to LAX.
# From DTW to SAN.
# From DTW to PHL.
# From DTW to DFW.
# From DTW to LAS.
# From DTW to ATL.
# From DTW to TPA.
# From DTW to MIA.
# From DTW to SJC.
# From DTW to SBA.
# From DTW to PHX.
# From DTW to SJU.
# From DTW to SAT.
# From DTW to SFO.
# From DTW to SNA.
# From DTW to CHS.
# From DTW to BWI.
# From DTW to AYT.
# From DTW to TSE.
# From DTW to TAM.
# From DTW to DXB.
# From DTW to MAF.
# From DTW to MEX.
# From DTW to BOM.
# From DTW to DEL.
# From DTW to HNL.
# From DTW to TPE.
# From DTW to CNS.
# From DTW to SEL.
# From DTW to TSV.
# From DTW to HYD.
# From DTW to SYD.
# Searching flights out of MSP
# From MSP to ORL.
# From MSP to ATL.
# From MSP to BWI.
# From MSP to PHX.
# From MSP to LAS.
# From MSP to DFW.
# From MSP to MIA.
# From MSP to FLL.
# From MSP to FLO.
# From MSP to SLC.
# From MSP to NYC.
# From MSP to DEN.
# From MSP to FMY.
# From MSP to LAX.
# From MSP to PHL.
# From MSP to HVN.
# From MSP to CHI.
# From MSP to BNA.
# From MSP to HOU.
# From MSP to MEX.
# From MSP to ISP.
# From MSP to SJU.
# From MSP to SAT.
# From MSP to SBN.
# From MSP to SDQ.
# From MSP to ATW.
# From MSP to BDL.
# From MSP to GJT.
# From MSP to CSL.
# From MSP to MOB.
# From MSP to DAB.
# From MSP to KOA.
# From MSP to QRO.
# From MSP to BRU.
# From MSP to DLH.
# From MSP to RIX.
# From MSP to LIS.
# From MSP to BRO.
# From MSP to CAN.
# From MSP to ABJ.
# From MSP to CUZ.
# From MSP to NBO.
# From MSP to MLW.
# Searching flights out of SEA
# From SEA to LAS.
# From SEA to RDM.
# From SEA to BOI.
# From SEA to SJC.
# From SEA to YVR.
# From SEA to DEN.
# From SEA to LAX.
# From SEA to STL.
# From SEA to PHX.
# From SEA to NYC.
# From SEA to ANC.
# From SEA to AUS.
# From SEA to FLL.
# From SEA to ONT.
# From SEA to SAC.
# From SEA to AVP.
# From SEA to ATL.
# From SEA to RDU.
# From SEA to MRY.
# From SEA to PVR.
# From SEA to TUS.
# From SEA to ABQ.
# From SEA to ISP.
# From SEA to HNL.
# From SEA to OGG.
# From SEA to GDL.
# From SEA to HAV.
# From SEA to BNA.
# From SEA to HOU.
# From SEA to IDA.
# From SEA to LON.
# From SEA to GCC.
# From SEA to MOW.
# From SEA to MIL.
# From SEA to PAR.
# From SEA to PNH.
# From SEA to AMS.
# From SEA to CAN.
# From SEA to ROM.
# From SEA to FRA.
# From SEA to IST.
# From SEA to VIE.
# From SEA to IBZ.
# From SEA to BCN.
# From SEA to LED.
# From SEA to BOM.
# From SEA to LWO.
# From SEA to CAI.
# From SEA to OMS.
# From SEA to FUK.
# From SEA to KGD.
# From SEA to BLR.
# From SEA to DEL.
# From SEA to EBL.
# From SEA to AKL.
# Searching flights out of PHL
# From PHL to ORL.
# From PHL to FLL.
# From PHL to DFW.
# From PHL to DEN.
# From PHL to LAX.
# From PHL to SJU.
# From PHL to DTT.
# From PHL to MIA.
# From PHL to WAS.
# From PHL to PIT.
# From PHL to CHI.
# From PHL to AUS.
# From PHL to NYC.
# From PHL to LAS.
# From PHL to BWI.
# From PHL to HOU.
# From PHL to YTO.
# From PHL to TPA.
# From PHL to MSY.
# From PHL to MYR.
# From PHL to SFO.
# From PHL to YMQ.
# From PHL to HGR.
# From PHL to ATL.
# From PHL to OAK.
# From PHL to BOS.
# From PHL to PHX.
# From PHL to HAR.
# From PHL to FAY.
# From PHL to PVD.
# From PHL to MSP.
# From PHL to BFD.
# From PHL to SBN.
# From PHL to BHM.
# From PHL to MKE.
# From PHL to GRB.
# From PHL to MBJ.
# From PHL to HYA.
# From PHL to AVP.
# From PHL to CID.
# From PHL to LON.
# From PHL to HNL.
# From PHL to MSN.
# From PHL to LIM.
# From PHL to FYV.
# From PHL to BER.
# From PHL to DUJ.
# From PHL to LNS.
# From PHL to MGW.
# From PHL to AOO.
# From PHL to JST.
# From PHL to LED.
# From PHL to PNS.
# From PHL to HER.
# From PHL to MOW.
# From PHL to FKL.
# From PHL to ROM.
# From PHL to NBC.
# From PHL to MAA.
# From PHL to SEL.
# From PHL to MEM.
# From PHL to VNS.
# From PHL to DEL.
# Searching flights out of BOS
# From BOS to BUF.
# From BOS to FLL.
# From BOS to ATL.
# From BOS to NYC.
# From BOS to SYR.
# From BOS to MIA.
# From BOS to YTO.
# From BOS to LAX.
# From BOS to TPA.
# From BOS to BNA.
# From BOS to ROC.
# From BOS to ORL.
# From BOS to REK.
# From BOS to CHS.
# From BOS to STT.
# From BOS to STI.
# From BOS to PHX.
# From BOS to SJU.
# From BOS to SAN.
# From BOS to LON.
# From BOS to SDQ.
# From BOS to BCN.
# From BOS to SJC.
# From BOS to POP.
# From BOS to HSV.
# From BOS to SAV.
# From BOS to BER.
# From BOS to CHI.
# From BOS to PAR.
# From BOS to LIS.
# From BOS to SFO.
# From BOS to DFW.
# From BOS to FRA.
# From BOS to CPH.
# From BOS to AUS.
# From BOS to OSL.
# From BOS to LAS.
# From BOS to VCE.
# From BOS to ROM.
# From BOS to OAK.
# From BOS to SEA.
# From BOS to FMY.
# From BOS to LGB.
# From BOS to MBJ.
# From BOS to ISP.
# From BOS to MSQ.
# From BOS to BEY.
# From BOS to IST.
# From BOS to LED.
# From BOS to MOW.
# From BOS to SHA.
# From BOS to EDI.
# From BOS to MAD.
# From BOS to CAS.
# From BOS to BJS.
# From BOS to BRU.
# From BOS to LHE.
# From BOS to JKT.
# From BOS to HYD.
# From BOS to KTM.
# From BOS to FDH.
# From BOS to MEL.
# From BOS to SVX.
# From BOS to MAA.
# Searching flights out of LGA
# From LGA to FLL.
# From LGA to MIA.
# From LGA to CHI.
# From LGA to DFW.
# From LGA to BOS.
# From LGA to YTO.
# From LGA to WAS.
# From LGA to BUF.
# From LGA to DTT.
# From LGA to CLT.
# From LGA to YMQ.
# From LGA to CVG.
# From LGA to BWI.
# From LGA to ORL.
# From LGA to DEN.
# From LGA to ATL.
# From LGA to PIT.
# From LGA to MSY.
# From LGA to CMH.
# From LGA to CAE.
# From LGA to LEX.
# From LGA to LAX.
# From LGA to MEX.
# From LGA to HOU.
# From LGA to LAS.
# From LGA to PTY.
# From LGA to PDX.
# From LGA to MDE.
# From LGA to JAX.
# From LGA to PWM.
# From LGA to SJU.
# From LGA to GCM.
# From LGA to RDU.
# From LGA to PBI.
# From LGA to SAC.
# From LGA to DAY.
# From LGA to SJC.
# From LGA to ONT.
# From LGA to BQN.
# From LGA to ATW.
# From LGA to YVR.
# From LGA to SJO.
# From LGA to LIT.
# From LGA to SFO.
# From LGA to STI.
# From LGA to PHX.
# From LGA to CUN.
# From LGA to SAP.
# From LGA to PHL.
# From LGA to TPA.
# From LGA to AXM.
# From LGA to NAS.
# From LGA to SAN.
# From LGA to PAP.
# From LGA to AUS.
# From LGA to STT.
# From LGA to SDQ.
# From LGA to SEA.
# From LGA to HAV.
# From LGA to AVP.
# From LGA to SAL.
# From LGA to MBJ.
# From LGA to POS.
# From LGA to BGI.
# From LGA to YQB.
# From LGA to EYW.
# From LGA to PUJ.
# From LGA to LAN.
# From LGA to AUA.
# From LGA to ILM.
# From LGA to IND.
# From LGA to LAR.
# From LGA to CTG.
# From LGA to HRL.
# From LGA to CLO.
# From LGA to HAR.
# From LGA to STL.
# From LGA to OAK.
# From LGA to IAG.
# From LGA to LON.
# From LGA to SBY.
# From LGA to HGR.
# From LGA to DUB.
# From LGA to ANC.
# From LGA to BRU.
# From LGA to POP.
# From LGA to LGB.
# From LGA to SRQ.
# From LGA to BFD.
# From LGA to AOO.
# From LGA to BUR.
# From LGA to DUJ.
# From LGA to FKL.
# From LGA to MGW.
# From LGA to LNS.
# From LGA to PAR.
# From LGA to VNO.
# From LGA to GUA.
# From LGA to MAD.
# From LGA to MIL.
# From LGA to JNU.
# From LGA to CYB.
# From LGA to AGP.
# From LGA to NCE.
# From LGA to BER.
# From LGA to VCE.
# From LGA to LIS.
# From LGA to VRA.
# From LGA to ATH.
# From LGA to UIO.
# From LGA to ROA.
# From LGA to FRA.
# From LGA to TLV.
# From LGA to STR.
# From LGA to IST.
# From LGA to RIX.
# From LGA to JST.
# From LGA to BCN.
# From LGA to WAW.
# From LGA to MFE.
# From LGA to BRO.
# From LGA to REK.
# From LGA to ORN.
# From LGA to ROM.
# From LGA to BJS.
# From LGA to MOW.
# From LGA to LPB.
# From LGA to KUL.
# From LGA to LED.
# From LGA to HNL.
# From LGA to HEL.
# From LGA to TBS.
# From LGA to ALG.
# From LGA to CTU.
# From LGA to CAS.
# From LGA to KUT.
# From LGA to SGN.
# From LGA to KIN.
# From LGA to VIE.
# From LGA to ISB.
# From LGA to SHA.
# From LGA to CAN.
# From LGA to AMM.
# From LGA to AYT.
# From LGA to BHX.
# From LGA to SVD.
# From LGA to DEL.
# From LGA to RIO.
# From LGA to IEV.
# From LGA to OSL.
# From LGA to VVO.
# From LGA to ACC.
# From LGA to MSQ.
# From LGA to STO.
# From LGA to KHI.
# From LGA to EVN.
# From LGA to MUC.
# From LGA to BUE.
# From LGA to CAI.
# From LGA to HKG.
# From LGA to TUN.
# From LGA to ABJ.
# From LGA to SAO.
# From LGA to NKC.
# From LGA to KIV.
# From LGA to TYO.
# From LGA to BOM.
# From LGA to SEL.
# From LGA to AUH.
# From LGA to DPS.
# From LGA to BEG.
# From LGA to BLR.
# From LGA to ALA.
# From LGA to SYD.
# From LGA to LOS.
# From LGA to NGO.
# From LGA to DXB.
# From LGA to JAI.
# From LGA to SSA.
# From LGA to OVB.
# From LGA to TGD.
# From LGA to BAH.
# From LGA to JTR.
# From LGA to OUA.
# From LGA to KTM.
# From LGA to FRU.
# From LGA to CPT.
# From LGA to AMD.
# From LGA to HRE.
# From LGA to LHE.
# From LGA to MLW.
# From LGA to TAS.
# From LGA to BKO.
# From LGA to HNY.
# From LGA to MEL.
# From LGA to GVA.
# From LGA to BAK.
# From LGA to GUM.
# From LGA to NKG.
# From LGA to BEY.
# From LGA to UUS.
# From LGA to SIP.
# From LGA to MED.
# From LGA to BUS.
# From LGA to FOC.
# From LGA to MNL.
# From LGA to MAA.
# From LGA to KZO.
# From LGA to ASB.
# From LGA to SUF.
# From LGA to KGD.
# From LGA to ROV.
# From LGA to SMA.
# Searching flights out of IAD
# From IAD to NYC.
# From IAD to ORL.
# From IAD to LAS.
# From IAD to DEN.
# From IAD to BOS.
# From IAD to RDU.
# From IAD to AUS.
# From IAD to FLL.
# From IAD to CAK.
# From IAD to TPA.
# From IAD to MIA.
# From IAD to CLT.
# From IAD to CLE.
# From IAD to ATL.
# From IAD to OMA.
# From IAD to BNA.
# From IAD to CHS.
# From IAD to STL.
# From IAD to PIT.
# From IAD to YTO.
# From IAD to SJC.
# From IAD to DFW.
# From IAD to LAX.
# From IAD to COS.
# From IAD to PHL.
# From IAD to CHI.
# From IAD to CKB.
# From IAD to SDF.
# From IAD to BWI.
# From IAD to MEM.
# From IAD to FMY.
# From IAD to OAK.
# From IAD to SAT.
# From IAD to AVP.
# From IAD to SAV.
# From IAD to SFO.
# From IAD to SAC.
# From IAD to RIC.
# From IAD to LAN.
# From IAD to HOU.
# From IAD to CID.
# From IAD to PHX.
# From IAD to ELP.
# From IAD to DTT.
# From IAD to YOW.
# From IAD to BOG.
# From IAD to HAR.
# From IAD to ALB.
# From IAD to SDQ.
# From IAD to LEX.
# From IAD to SLN.
# From IAD to EVV.
# From IAD to BJX.
# From IAD to ORF.
# From IAD to VPS.
# From IAD to LON.
# From IAD to SEA.
# From IAD to SAL.
# From IAD to UBS.
# From IAD to PGV.
# From IAD to TUL.
# From IAD to PAR.
# From IAD to GUA.
# From IAD to MSY.
# From IAD to ERI.
# From IAD to GSO.
# From IAD to NCE.
# From IAD to CRP.
# From IAD to SCE.
# From IAD to TBN.
# From IAD to JMS.
# From IAD to BRD.
# From IAD to LED.
# From IAD to FNT.
# From IAD to CSL.
# From IAD to MOW.
# From IAD to KOA.
# From IAD to ROM.
# From IAD to SIN.
# From IAD to DXB.
# From IAD to CAI.
# From IAD to FRO.
# From IAD to LIH.
# From IAD to FOC.
# From IAD to SVX.
# From IAD to MAA.
# From IAD to ULN.
# From IAD to HYD.
# From IAD to TYO.
# From IAD to TLV.
# From IAD to DEL.
# From IAD to JED.
# From IAD to LHE.
# From IAD to HRG.
# From IAD to ALG.
# From IAD to SHJ.
# From IAD to CBR.
# From IAD to BAL.
# From IAD to AMD.
# From IAD to PGH.
# From IAD to JST.
# From IAD to AOO.
# From IAD to LNS.
# Searching flights out of BWI
# From BWI to PIT.
# From BWI to VPS.
# From BWI to ATL.
# From BWI to DEN.
# From BWI to FLL.
# From BWI to ORL.
# From BWI to HOU.
# From BWI to DFW.
# From BWI to TPA.
# From BWI to RDU.
# From BWI to MSP.
# From BWI to FMY.
# From BWI to NYC.
# From BWI to LAS.
# From BWI to LAX.
# From BWI to CLE.
# From BWI to CAK.
# From BWI to DAY.
# From BWI to CLT.
# From BWI to GSO.
# From BWI to BNA.
# From BWI to OMA.
# From BWI to PHL.
# From BWI to LAN.
# From BWI to MBJ.
# From BWI to MIA.
# From BWI to SFO.
# From BWI to BUF.
# From BWI to ISP.
# From BWI to DTT.
# From BWI to OAK.
# From BWI to JAX.
# From BWI to CHS.
# From BWI to STL.
# From BWI to SAT.
# From BWI to ERI.
# From BWI to MEM.
# From BWI to SJC.
# From BWI to SAV.
# From BWI to RIC.
# From BWI to ELP.
# From BWI to WAS.
# From BWI to MLM.
# From BWI to PHX.
# From BWI to AUS.
# From BWI to ORF.
# From BWI to MSY.
# From BWI to BTV.
# From BWI to CRP.
# From BWI to EVV.
# From BWI to BJX.
# From BWI to ALB.
# From BWI to PGV.
# From BWI to LEX.
# From BWI to MFE.
# From BWI to PNS.
# From BWI to UBS.
# From BWI to TUL.
# From BWI to CKB.
# From BWI to HSV.
# From BWI to BRD.
# From BWI to FWA.
# From BWI to KUN.
# From BWI to CID.
# From BWI to LON.
# From BWI to MOB.
# From BWI to MGM.
# From BWI to FNT.
# From BWI to SCE.
# From BWI to SJU.
# From BWI to JMS.
# From BWI to REK.
# From BWI to VNO.
# From BWI to SAO.
# From BWI to RAK.
# From BWI to TJM.
# From BWI to DEL.
# From BWI to BAL.
# Searching flights out of FLL
# From FLL to AVL.
# From FLL to CHI.
# From FLL to MSY.
# From FLL to BWI.
# From FLL to BOS.
# From FLL to NYC.
# From FLL to PIT.
# From FLL to TPA.
# From FLL to BDL.
# From FLL to ORL.
# From FLL to ATL.
# From FLL to HOU.
# From FLL to DTT.
# From FLL to PTY.
# From FLL to RDU.
# From FLL to SAN.
# From FLL to DFW.
# From FLL to YTO.
# From FLL to PAP.
# From FLL to SJU.
# From FLL to ISP.
# From FLL to ILM.
# From FLL to WAS.
# From FLL to MEX.
# From FLL to GCM.
# From FLL to LAX.
# From FLL to AUS.
# From FLL to YQB.
# From FLL to ORF.
# From FLL to MEM.
# From FLL to SDQ.
# From FLL to NAS.
# From FLL to STT.
# From FLL to POS.
# From FLL to LIT.
# From FLL to STL.
# From FLL to IAG.
# From FLL to CLE.
# From FLL to SJO.
# From FLL to HGR.
# From FLL to EYW.
# From FLL to HAV.
# From FLL to LAS.
# From FLL to OMA.
# From FLL to BNA.
# From FLL to ABQ.
# From FLL to PHF.
# From FLL to AUA.
# From FLL to BQN.
# From FLL to UIO.
# From FLL to CMH.
# From FLL to HAR.
# From FLL to MGA.
# From FLL to PVD.
# From FLL to AVP.
# From FLL to PUJ.
# From FLL to SFO.
# From FLL to PAR.
# From FLL to PVR.
# From FLL to OAK.
# From FLL to GND.
# From FLL to DEN.
# From FLL to LON.
# From FLL to YMQ.
# From FLL to TXK.
# From FLL to YEA.
# From FLL to SLC.
# From FLL to FKL.
# From FLL to PBI.
# From FLL to AOO.
# From FLL to MGW.
# From FLL to BFD.
# From FLL to BOG.
# From FLL to DUJ.
# From FLL to MAD.
# From FLL to SXM.
# From FLL to OSL.
# From FLL to LNS.
# From FLL to VCE.
# From FLL to MDE.
# From FLL to SEA.
# From FLL to IEV.
# From FLL to FSM.
# From FLL to DUS.
# From FLL to MOW.
# From FLL to MTY.
# From FLL to STO.
# From FLL to DUB.
# From FLL to SAP.
# From FLL to BZE.
# From FLL to LPA.
# From FLL to CCS.
# From FLL to LPB.
# From FLL to GUA.
# From FLL to HNL.
# From FLL to RIO.
# From FLL to SAO.
# From FLL to CLO.
# From FLL to SHA.
# From FLL to LIS.
# From FLL to BER.
# From FLL to NAT.
# From FLL to JPA.
# From FLL to PDX.
# From FLL to REK.
# From FLL to ALA.
# From FLL to SGN.
# From FLL to BCN.
# From FLL to MUC.
# From FLL to BRU.
# From FLL to SCL.
# From FLL to PEI.
# From FLL to SJP.
# From FLL to KGF.
# From FLL to LED.
# From FLL to SSA.
# From FLL to BKK.
# From FLL to ROM.
# From FLL to SHE.
# From FLL to VLC.
# From FLL to POA.
# From FLL to AMS.
# From FLL to HMO.
# From FLL to IST.
# From FLL to ATH.
# From FLL to ABJ.
# From FLL to BUE.
# From FLL to BUH.
# From FLL to ACC.
# From FLL to SOF.
# From FLL to JER.
# From FLL to MSQ.
# From FLL to ODS.
# From FLL to GVA.
# From FLL to NAP.
# From FLL to DPS.
# From FLL to DXB.
# From FLL to KRR.
# Searching flights out of SLC
# From SLC to LAX.
# From SLC to LAS.
# From SLC to DEN.
# From SLC to SAN.
# From SLC to DFW.
# From SLC to AUS.
# From SLC to NYC.
# From SLC to SEA.
# From SLC to HOU.
# From SLC to ISP.
# From SLC to YMQ.
# From SLC to ALB.
# From SLC to BRL.
# From SLC to SAT.
# From SLC to MSP.
# From SLC to CLT.
# From SLC to MLM.
# From SLC to MOW.
# From SLC to VCE.
# From SLC to IEV.
# Searching flights out of HNL
# From HNL to LIH.
# From HNL to ITO.
# From HNL to LAX.
# From HNL to OSA.
# From HNL to PDX.
# From HNL to SFO.
# From HNL to LGB.
# From HNL to SEA.
# From HNL to SNA.
# From HNL to OAK.
# From HNL to RDM.
# From HNL to OKC.
# From HNL to CVG.
# From HNL to SJU.
# From HNL to NYC.
# From HNL to HKG.
# From HNL to ORL.
# From HNL to DFW.
# From HNL to HOU.
# From HNL to SBA.
# From HNL to TYO.
# From HNL to MNL.
# From HNL to MKC.
# From HNL to BNA.
# From HNL to ATL.
# From HNL to CLT.
# From HNL to SYD.
# From HNL to MKE.
# From HNL to MAF.
# From HNL to FRA.
# From HNL to BWI.
# From HNL to PHF.
# From HNL to ROM.
# From HNL to PPT.
# From HNL to BCN.
# From HNL to IEV.
# From HNL to MAJ.
# From HNL to TKK.
# Searching flights out of DCA
# From DCA to LAS.
# From DCA to BOS.
# From DCA to ORL.
# From DCA to RDU.
# From DCA to DEN.
# From DCA to NYC.
# From DCA to CAK.
# From DCA to CLE.
# From DCA to FLL.
# From DCA to TPA.
# From DCA to MIA.
# From DCA to CLT.
# From DCA to ATL.
# From DCA to CHI.
# From DCA to YTO.
# From DCA to OMA.
# From DCA to BNA.
# From DCA to CHS.
# From DCA to STL.
# From DCA to PIT.
# From DCA to DFW.
# From DCA to COS.
# From DCA to LAX.
# From DCA to PHL.
# From DCA to FMY.
# From DCA to ERI.
# From DCA to OAK.
# From DCA to BWI.
# From DCA to MEM.
# From DCA to HAR.
# From DCA to SDF.
# From DCA to LAN.
# From DCA to SAT.
# From DCA to HOU.
# From DCA to SFO.
# From DCA to SAC.
# From DCA to PHX.
# From DCA to SAV.
# From DCA to AVP.
# From DCA to ELP.
# From DCA to DTT.
# From DCA to YOW.
# From DCA to AUS.
# From DCA to SDQ.
# From DCA to BOG.
# From DCA to LEX.
# From DCA to ALB.
# From DCA to RIC.
# From DCA to SLN.
# From DCA to EVV.
# From DCA to BJX.
# From DCA to GSO.
# From DCA to SEA.
# From DCA to UBS.
# From DCA to VPS.
# From DCA to PGV.
# From DCA to ORF.
# From DCA to LON.
# From DCA to FNT.
# From DCA to TUL.
# From DCA to PAR.
# From DCA to GUA.
# From DCA to TBN.
# From DCA to MSY.
# From DCA to CRP.
# From DCA to FKL.
# From DCA to ISP.
# From DCA to CID.
# From DCA to NCE.
# From DCA to SJC.
# From DCA to MGW.
# From DCA to BRD.
# From DCA to SAL.
# From DCA to AOO.
# From DCA to JMS.
# From DCA to DUJ.
# From DCA to JST.
# From DCA to BFD.
# From DCA to HGR.
# From DCA to CSL.
# From DCA to KOA.
# From DCA to MOW.
# From DCA to SCE.
# From DCA to LED.
# From DCA to FOC.
# From DCA to LIH.
# From DCA to CKB.
# From DCA to MAA.
# From DCA to ROM.
# From DCA to HYD.
# From DCA to ULN.
# From DCA to DXB.
# From DCA to DEL.
# From DCA to FRO.
# From DCA to SIN.
# From DCA to CAI.
# From DCA to ALG.
# From DCA to TLV.
# From DCA to SVX.
# From DCA to TYO.
# From DCA to CBR.
# From DCA to JED.
# From DCA to LHE.
# From DCA to PGH.
# From DCA to AMD.
# From DCA to HRG.
# Searching flights out of MDW
# From MDW to BOS.
# From MDW to NYC.
# From MDW to CMH.
# From MDW to SDF.
# From MDW to ISP.
# From MDW to YTO.
# From MDW to FLL.
# From MDW to RDU.
# From MDW to DEN.
# From MDW to ORL.
# From MDW to SFO.
# From MDW to PBI.
# From MDW to MSP.
# From MDW to MLB.
# From MDW to CLE.
# From MDW to MIA.
# From MDW to SEA.
# From MDW to LAX.
# From MDW to SJU.
# From MDW to BNA.
# From MDW to AUS.
# From MDW to WAS.
# From MDW to PHL.
# From MDW to CLT.
# From MDW to SAN.
# From MDW to PDX.
# From MDW to ATL.
# From MDW to DFW.
# From MDW to LAS.
# From MDW to BWI.
# From MDW to OAK.
# From MDW to MEX.
# From MDW to YHZ.
# From MDW to BJX.
# From MDW to MSY.
# From MDW to QRO.
# From MDW to PHX.
# From MDW to ABQ.
# From MDW to DTT.
# From MDW to SNA.
# From MDW to YMQ.
# From MDW to GDL.
# From MDW to CJS.
# From MDW to PIT.
# From MDW to STI.
# From MDW to GSO.
# From MDW to SJC.
# From MDW to MLM.
# From MDW to FMY.
# From MDW to LON.
# From MDW to JAN.
# From MDW to GUA.
# From MDW to AUA.
# From MDW to SYR.
# From MDW to RIC.
# From MDW to HOU.
# From MDW to HAR.
# From MDW to SAC.
# From MDW to PUJ.
# From MDW to ROM.
# From MDW to AMS.
# From MDW to MTY.
# From MDW to BCN.
# From MDW to ANC.
# From MDW to VER.
# From MDW to YVR.
# From MDW to MAN.
# From MDW to MUC.
# From MDW to MLA.
# From MDW to CEB.
# From MDW to BEG.
# From MDW to MNL.
# From MDW to KWI.
# From MDW to DEL.
# From MDW to ZRH.
# From MDW to SKG.
# From MDW to MOW.
# From MDW to IEV.
# From MDW to DXB.
# From MDW to CAI.
# From MDW to DPS.
# From MDW to HNL.
# From MDW to TYO.
# From MDW to SCL.
# From MDW to CTA.
# From MDW to PAR.
# From MDW to ATQ.
# From MDW to BOM.
# From MDW to KHI.
# From MDW to IST.
# From MDW to PNQ.
# From MDW to SEL.
# From MDW to CAN.
# From MDW to PRG.
# From MDW to GRX.
# From MDW to LED.
# From MDW to MSQ.
# From MDW to LFW.
# From MDW to JST.
# Searching flights out of SAN
# From SAN to SFO.
# From SAN to LAS.
# From SAN to PIT.
# From SAN to OAK.
# From SAN to SAT.
# From SAN to LAX.
# From SAN to SLC.
# From SAN to FAT.
# From SAN to AUS.
# From SAN to OMA.
# From SAN to DEN.
# From SAN to CHI.
# From SAN to DFW.
# From SAN to COS.
# From SAN to BOS.
# From SAN to ELP.
# From SAN to ORL.
# From SAN to NYC.
# From SAN to DTT.
# From SAN to MSY.
# From SAN to WAS.
# From SAN to BOI.
# From SAN to SEA.
# From SAN to FLL.
# From SAN to LBB.
# From SAN to MEM.
# From SAN to ISP.
# From SAN to ZRH.
# From SAN to ATL.
# From SAN to PAR.
# From SAN to OKA.
# From SAN to CAS.
# From SAN to TLV.
# From SAN to HYD.
# From SAN to AMM.
# From SAN to KBL.
# From SAN to CAY.
# Searching flights out of TPA
# From TPA to MIA.
# From TPA to FLL.
# From TPA to MSY.
# From TPA to DFW.
# From TPA to PIT.
# From TPA to BWI.
# From TPA to MKE.
# From TPA to WAS.
# From TPA to DTT.
# From TPA to CLE.
# From TPA to NYC.
# From TPA to YTO.
# From TPA to SEA.
# From TPA to PHL.
# From TPA to BNA.
# From TPA to ISP.
# From TPA to EYW.
# From TPA to DEN.
# From TPA to PTY.
# From TPA to SAN.
# From TPA to LYH.
# From TPA to FSD.
# From TPA to LAX.
# From TPA to YMQ.
# From TPA to SJU.
# From TPA to CVG.
# From TPA to MEM.
# From TPA to MSP.
# From TPA to PAR.
# From TPA to HAV.
# From TPA to VCE.
# From TPA to LUL.
# From TPA to HAR.
# From TPA to IEV.
# From TPA to MDE.
# From TPA to LIS.
# From TPA to BOM.
# From TPA to DEL.
# From TPA to OVB.
# From TPA to HKG.
# From TPA to HKT.
# Searching flights out of PDX
# From PDX to SEA.
# From PDX to PHX.
# From PDX to LAX.
# From PDX to BUR.
# From PDX to LAS.
# From PDX to SAN.
# From PDX to SNA.
# From PDX to OAK.
# From PDX to YVR.
# From PDX to CHI.
# From PDX to STL.
# From PDX to SAC.
# From PDX to RDU.
# From PDX to ATL.
# From PDX to FAT.
# From PDX to DFW.
# From PDX to SFO.
# From PDX to BUF.
# From PDX to MSY.
# From PDX to IDA.
# From PDX to BJX.
# From PDX to ONT.
# From PDX to HNL.
# From PDX to GDL.
# From PDX to SBN.
# From PDX to NYC.
# From PDX to CLT.
# From PDX to MID.
# From PDX to MLM.
# From PDX to VER.
# From PDX to IEV.
# From PDX to BCN.
# From PDX to DUB.
# From PDX to PNH.
# From PDX to LWO.
# From PDX to GLA.
# From PDX to CPH.
# From PDX to JNU.
# From PDX to SCL.
# From PDX to AMS.
# From PDX to SIT.
# From PDX to TKK.
# Searching flights out of STL
# From STL to IRK.
# From STL to PIT.
# From STL to LAX.
# From STL to LAS.
# From STL to WAS.
# From STL to GPT.
# From STL to NYC.
# From STL to JAX.
# From STL to BWI.
# From STL to FLL.
# From STL to TXK.
# From STL to CRP.
# From STL to DFW.
# From STL to CLE.
# From STL to ISP.
# From STL to MEM.
# From STL to PGD.
# From STL to SEA.
# From STL to ANC.
# From STL to GCN.
# From STL to DPS.
# From STL to HYD.
# From STL to GYS.
# From STL to MDZ.
# Searching flights out of MCI
# From MCI to LAS.
# From MCI to LAX.
# From MCI to VPS.
# From MCI to DFW.
# From MCI to ATL.
# From MCI to MEM.
# From MCI to OAK.
# From MCI to CHI.
# From MCI to FLL.
# From MCI to FMY.
# From MCI to BHM.
# From MCI to SAC.
# From MCI to JAX.
# From MCI to SFO.
# From MCI to PDX.
# From MCI to WAS.
# From MCI to MIA.
# From MCI to YYC.
# From MCI to IRK.
# From MCI to MOB.
# From MCI to TLH.
# From MCI to MYR.
# From MCI to DHN.
# From MCI to SKG.
# From MCI to JKT.
# From MCI to SGN.
# From MCI to JED.
# Searching flights out of MEM
# From MEM to ORL.
# From MEM to ATL.
# From MEM to DFW.
# From MEM to DSM.
# From MEM to CHI.
# From MEM to MKC.
# From MEM to BWI.
# From MEM to SFO.
# From MEM to DEN.
# From MEM to MIA.
# From MEM to PHL.
# From MEM to HOU.
# From MEM to LAS.
# From MEM to FLL.
# From MEM to STL.
# From MEM to LIT.
# From MEM to BKG.
# From MEM to NYC.
# From MEM to MOT.
# From MEM to JAX.
# From MEM to OAK.
# From MEM to WAS.
# From MEM to AVP.
# From MEM to FAY.
# From MEM to ISP.
# From MEM to PIT.
# From MEM to SYR.
# From MEM to CKB.
# From MEM to LNS.
# From MEM to SDQ.
# From MEM to TYS.
# From MEM to SAN.
# From MEM to FYV.
# From MEM to HGR.
# From MEM to DUJ.
# From MEM to MGW.
# From MEM to GDL.
# From MEM to BFD.
# From MEM to FKL.
# From MEM to AOO.
# From MEM to SEA.
# From MEM to MKE.
# From MEM to PHX.
# From MEM to PFN.
# From MEM to HAR.
# From MEM to ISN.
# From MEM to DRO.
# From MEM to BTR.
# From MEM to BPN.
# Searching flights out of MKE
# From MKE to ORL.
# From MKE to DFW.
# From MKE to LAX.
# From MKE to CMH.
# From MKE to BNA.
# From MKE to SJU.
# From MKE to AUS.
# From MKE to QRO.
# From MKE to BGI.
# From MKE to MEM.
# Searching flights out of OAK
# From OAK to LAS.
# From OAK to LAX.
# From OAK to PHX.
# From OAK to SEA.
# From OAK to DTT.
# From OAK to PDX.
# From OAK to SAN.
# From OAK to HOU.
# From OAK to CHI.
# From OAK to CLE.
# From OAK to CMH.
# From OAK to PHL.
# From OAK to LGB.
# From OAK to FLL.
# From OAK to BWI.
# From OAK to NYC.
# From OAK to DFW.
# From OAK to BOS.
# From OAK to MEX.
# From OAK to IND.
# From OAK to PSP.
# From OAK to OMA.
# From OAK to ATL.
# From OAK to MTY.
# From OAK to GDL.
# From OAK to YYC.
# From OAK to OSL.
# From OAK to ISP.
# From OAK to BDL.
# From OAK to BJX.
# From OAK to PAR.
# From OAK to GSO.
# From OAK to CVG.
# From OAK to MSY.
# From OAK to ABQ.
# From OAK to VER.
# From OAK to AGU.
# From OAK to LON.
# From OAK to TIJ.
# From OAK to MLM.
# From OAK to PIT.
# From OAK to OAX.
# From OAK to MIA.
# From OAK to HNL.
# From OAK to MID.
# From OAK to WAS.
# From OAK to MSP.
# From OAK to STL.
# From OAK to SNA.
# From OAK to SHA.
# From OAK to MBJ.
# From OAK to SDQ.
# From OAK to DXB.
# From OAK to DUB.
# From OAK to BUF.
# From OAK to HKG.
# From OAK to BCN.
# From OAK to BJS.
# From OAK to CTU.
# From OAK to CLT.
# From OAK to CAN.
# From OAK to IEV.
# From OAK to SIN.
# From OAK to HEL.
# From OAK to FRA.
# From OAK to SGN.
# From OAK to BKK.
# From OAK to AMS.
# From OAK to KUL.
# From OAK to EYW.
# From OAK to TYS.
# From OAK to CAI.
# From OAK to SIA.
# From OAK to HKT.
# From OAK to NKG.
# From OAK to DAC.
# From OAK to GGT.
# From OAK to MNL.
# From OAK to BOM.
# From OAK to WLG.
# From OAK to DUS.
# From OAK to PPT.
# From OAK to TLV.
# From OAK to DEL.
# From OAK to YTO.
# From OAK to BER.
# From OAK to MUX.
# From OAK to SCL.
# From OAK to BUE.
# From OAK to ISB.
# From OAK to TRV.
# From OAK to BLR.
# From OAK to AKL.
# From OAK to REC.
# From OAK to JPA.
# From OAK to HYD.
# From OAK to NAT.
# From OAK to SAO.
# From OAK to KHV.
# From OAK to JMK.
# From OAK to BEG.
# From OAK to MOW.
# From OAK to GOI.
# Searching flights out of CLE
# From CLE to ORL.
# From CLE to LAS.
# From CLE to DFW.
# From CLE to AUS.
# From CLE to DEN.
# From CLE to LAX.
# From CLE to FMY.
# From CLE to HOU.
# From CLE to BWI.
# From CLE to SAT.
# From CLE to WAS.
# From CLE to CHI.
# From CLE to ONT.
# From CLE to CHO.
# From CLE to SJU.
# From CLE to NYC.
# From CLE to PIT.
# From CLE to JAX.
# From CLE to SDQ.
# From CLE to ISP.
# From CLE to PDX.
# From CLE to GDL.
# From CLE to HNL.
# From CLE to ATL.
# From CLE to BJX.
# From CLE to LWO.
# From CLE to MEX.
# From CLE to MAN.
# From CLE to BHX.
# From CLE to GND.
# From CLE to PAR.
# From CLE to VCE.
# From CLE to DEL.
# Searching flights out of RDU
# From RDU to WAS.
# From RDU to BWI.
# From RDU to AUS.
# From RDU to NYC.
# From RDU to FLL.
# From RDU to HAR.
# From RDU to PIT.
# From RDU to TYS.
# From RDU to MBJ.
# From RDU to LAX.
# From RDU to AVP.
# From RDU to PHL.
# From RDU to CUN.
# From RDU to PHX.
# From RDU to HGR.
# From RDU to LNS.
# From RDU to ISP.
# From RDU to DUJ.
# From RDU to MGW.
# From RDU to JST.
# From RDU to FKL.
# From RDU to BFD.
# From RDU to AOO.
# From RDU to LPB.
# From RDU to MOW.
# From RDU to MNL.
# From RDU to KZN.
# From RDU to CAI.
# From RDU to OVB.
# From RDU to BGW.
# From RDU to DUB.
# Searching flights out of BNA
# From BNA to ORL.
# From BNA to ATL.
# From BNA to PIT.
# From BNA to DSM.
# From BNA to BWI.
# From BNA to WAS.
# From BNA to LIT.
# From BNA to VPS.
# From BNA to NAS.
# From BNA to DFW.
# From BNA to LAX.
# From BNA to CKB.
# From BNA to ABQ.
# From BNA to MKE.
# From BNA to NYC.
# From BNA to SJU.
# From BNA to BKG.
# From BNA to AVP.
# From BNA to TYS.
# From BNA to BFD.
# From BNA to JST.
# From BNA to MGW.
# From BNA to DUJ.
# From BNA to FKL.
# From BNA to AOO.
# From BNA to LAS.
# From BNA to HGR.
# From BNA to ATW.
# From BNA to PFN.
# From BNA to CHI.
# From BNA to STI.
# From BNA to FYV.
# From BNA to OAX.
# From BNA to ISP.
# From BNA to GDL.
# From BNA to PTY.
# From BNA to CLT.
# From BNA to HAR.
# From BNA to LNS.
# From BNA to PHX.
# From BNA to MSY.
# From BNA to BTR.
# From BNA to GYE.
# From BNA to AMS.
# From BNA to CHA.
# From BNA to DRO.
# From BNA to ZRH.
# From BNA to DXB.
# From BNA to SYX.
# Searching flights out of SMF
# From SMF to LAS.
# From SMF to LGB.
# From SMF to SAN.
# From SMF to GEG.
# From SMF to YVR.
# From SMF to CHI.
# From SMF to NYC.
# From SMF to PDX.
# From SMF to LAX.
# From SMF to BNA.
# From SMF to MEM.
# From SMF to WAS.
# From SMF to SFO.
# From SMF to PHL.
# From SMF to BUR.
# From SMF to ORL.
# From SMF to FLL.
# From SMF to GDL.
# From SMF to YWG.
# From SMF to DFW.
# From SMF to ASE.
# From SMF to RIC.
# From SMF to PHF.
# From SMF to IND.
# From SMF to PHX.
# From SMF to TYS.
# From SMF to DRO.
# From SMF to OKC.
# From SMF to ROV.
# From SMF to GUA.
# From SMF to FRA.
# From SMF to DEL.
# From SMF to ROM.
# From SMF to CGN.
# From SMF to TLV.
# From SMF to SPU.
# Searching flights out of HOU
# From HOU to DEN.
# From HOU to LAS.
# From HOU to LAX.
# From HOU to ORL.
# From HOU to MIA.
# From HOU to FLL.
# From HOU to NYC.
# From HOU to OAK.
# From HOU to CUN.
# From HOU to DFW.
# From HOU to JAX.
# From HOU to SAN.
# From HOU to BWI.
# From HOU to SAL.
# From HOU to PIT.
# From HOU to GEG.
# From HOU to PHL.
# From HOU to PDX.
# From HOU to MSY.
# From HOU to MEM.
# From HOU to CHI.
# From HOU to GDL.
# From HOU to MEX.
# From HOU to SLC.
# From HOU to EAT.
# From HOU to PVR.
# From HOU to DTT.
# From HOU to WAS.
# From HOU to ABQ.
# From HOU to EYW.
# From HOU to MBJ.
# From HOU to ISP.
# From HOU to GPT.
# From HOU to IND.
# From HOU to ROC.
# From HOU to HAV.
# From HOU to POS.
# From HOU to SJC.
# From HOU to JST.
# From HOU to DUJ.
# From HOU to MGW.
# From HOU to HGR.
# From HOU to AOO.
# From HOU to BHM.
# From HOU to BTR.
# From HOU to LON.
# From HOU to LNS.
# From HOU to CMW.
# From HOU to ELP.
# From HOU to PRG.
# From HOU to HSV.
# From HOU to BFS.
# From HOU to SDQ.
# From HOU to ORK.
# From HOU to GLA.
# From HOU to CEB.
# From HOU to SZG.
# From HOU to EVN.
# From HOU to BHX.
# From HOU to CEK.
# From HOU to SYD.
# From HOU to HYD.
# From HOU to BLR.
# From HOU to CMB.
# From HOU to ADD.
# From HOU to SSH.
# From HOU to MAD.
# From HOU to PMO.
# Searching flights out of SNA
# From SNA to SFO.
# From SNA to DEN.
# From SNA to PIT.
# From SNA to NYC.
# From SNA to CHI.
# From SNA to IND.
# From SNA to UDR.
# Searching flights out of SJU
# From SJU to STX.
# From SJU to ORL.
# From SJU to FLL.
# From SJU to PHL.
# From SJU to NYC.
# From SJU to CVG.
# From SJU to SDQ.
# From SJU to JAX.
# From SJU to ROC.
# From SJU to BDL.
# From SJU to BOS.
# From SJU to SYR.
# From SJU to TPA.
# From SJU to HAV.
# From SJU to MDE.
# From SJU to PTY.
# From SJU to CHI.
# From SJU to SDF.
# From SJU to MKE.
# From SJU to LAS.
# From SJU to CLT.
# From SJU to SAT.
# From SJU to MIA.
# From SJU to SFO.
# From SJU to LEX.
# From SJU to BNA.
# From SJU to ISP.
# From SJU to BUF.
# From SJU to CHS.
# From SJU to DFW.
# From SJU to YVR.
# From SJU to SEA.
# From SJU to AUS.
# From SJU to DTT.
# From SJU to RDU.
# From SJU to DEN.
# From SJU to OAK.
# From SJU to PHX.
# From SJU to NAS.
# From SJU to MSP.
# From SJU to OKC.
# From SJU to SGF.
# From SJU to CTG.
# From SJU to REK.
# From SJU to FRA.
# From SJU to VCE.
# From SJU to LIM.
# From SJU to COS.
# From SJU to BUE.
# From SJU to MAD.
# From SJU to SCL.
# From SJU to OKA.
# From SJU to MJV.
# From SJU to SYD.
# Searching flights out of AUS
# From AUS to CMH.
# From AUS to CLT.
# From AUS to CHS.
# From AUS to SAN.
# From AUS to MKE.
# From AUS to WAS.
# From AUS to ORL.
# From AUS to PIT.
# From AUS to BWI.
# From AUS to PHX.
# From AUS to MIA.
# From AUS to FLL.
# From AUS to DTT.
# From AUS to SJC.
# From AUS to GEG.
# From AUS to LGB.
# From AUS to PDX.
# From AUS to DFW.
# From AUS to MEX.
# From AUS to YTO.
# From AUS to GRR.
# From AUS to FNT.
# From AUS to CHI.
# From AUS to ICT.
# From AUS to PNS.
# From AUS to PFN.
# From AUS to MEM.
# From AUS to FMY.
# From AUS to FRA.
# From AUS to DAY.
# From AUS to SIN.
# Searching flights out of MSY
# From MSY to FLL.
# From MSY to CHI.
# From MSY to DFW.
# From MSY to LAS.
# From MSY to ORL.
# From MSY to HOU.
# From MSY to LAX.
# From MSY to NYC.
# From MSY to ONT.
# From MSY to MEM.
# From MSY to BWI.
# From MSY to TPA.
# From MSY to CUN.
# From MSY to CLT.
# From MSY to ISP.
# From MSY to DEN.
# From MSY to WAS.
# From MSY to BGR.
# From MSY to PIT.
# From MSY to MBJ.
# From MSY to MFR.
# From MSY to ERI.
# From MSY to BNA.
# From MSY to AUA.
# From MSY to STX.
# From MSY to AUS.
# From MSY to TRU.
# From MSY to YXE.
# From MSY to JAN.
# From MSY to ACV.
# From MSY to DPS.
# From MSY to BER.
# Searching flights out of SJC
# From SJC to PHX.
# From SJC to CHI.
# From SJC to TUS.
# From SJC to GDL.
# From SJC to DFW.
# From SJC to YTO.
# From SJC to NYC.
# From SJC to MEX.
# From SJC to PIT.
# From SJC to HAV.
# From SJC to MSY.
# From SJC to MLM.
# From SJC to TPE.
# From SJC to BUF.
# From SJC to ALA.
# From SJC to GSP.
# Searching flights out of PIT
# From PIT to ORL.
# From PIT to BWI.
# From PIT to FLL.
# From PIT to LAX.
# From PIT to TPA.
# From PIT to VPS.
# From PIT to FMY.
# From PIT to BNA.
# From PIT to ATL.
# From PIT to CLT.
# From PIT to NYC.
# From PIT to SDF.
# From PIT to PHL.
# From PIT to RDU.
# From PIT to OMA.
# From PIT to JAX.
# From PIT to DEN.
# From PIT to HOU.
# From PIT to STL.
# From PIT to MYR.
# From PIT to WAS.
# From PIT to DFW.
# From PIT to AIY.
# From PIT to SFO.
# From PIT to RIC.
# From PIT to CLE.
# From PIT to FWA.
# From PIT to MIA.
# From PIT to CAK.
# From PIT to ISP.
# From PIT to SAN.
# From PIT to DAB.
# From PIT to SAV.
# From PIT to BUF.
# From PIT to ELM.
# From PIT to LAS.
# From PIT to SDQ.
# From PIT to OAK.
# From PIT to PHX.
# From PIT to ELP.
# From PIT to AUS.
# From PIT to GSO.
# From PIT to CKB.
# From PIT to TUL.
# From PIT to EVV.
# From PIT to ORF.
# From PIT to MSY.
# From PIT to DTT.
# From PIT to FNT.
# From PIT to BTV.
# From PIT to MEM.
# From PIT to TBN.
# From PIT to BOG.
# From PIT to IEV.
# From PIT to UBS.
# From PIT to PGV.
# From PIT to JAN.
# From PIT to AMS.
# From PIT to GND.
# From PIT to CRP.
# From PIT to JMS.
# From PIT to SCE.
# From PIT to HAR.
# From PIT to FRO.
# From PIT to MNL.
# From PIT to SJC.
# From PIT to VCE.
# From PIT to CEK.
# From PIT to HRG.
# From PIT to LHE.
# From PIT to PGH.
# From PIT to BAL.
# Searching flights out of SAT
# From SAT to SNA.
# From SAT to MSY.
# From SAT to LAX.
# From SAT to NYC.
# From SAT to GDL.
# From SAT to DTT.
# From SAT to PIT.
# From SAT to ONT.
# From SAT to ISP.
# From SAT to PHL.
# From SAT to MEX.
# From SAT to MBJ.
# From SAT to HOU.
# From SAT to DFW.
# From SAT to SLC.
# From SAT to MKE.
# From SAT to RIX.
# Searching flights out of CVG
# From CVG to ATL.
# From CVG to FLL.
# From CVG to CHI.
# From CVG to BWI.
# From CVG to MIA.
# From CVG to SLC.
# From CVG to NYC.
# From CVG to SAN.
# From CVG to SFO.
# From CVG to ISP.
# From CVG to AMS.
# From CVG to OAK.
# From CVG to MSP.
# From CVG to HNL.
# From CVG to MAA.
# Searching flights out of DAL
# From DAL to DEN.
# From DAL to ATL.
# From DAL to FLL.
# From DAL to BWI.
# From DAL to TPA.
# From DAL to LAX.
# From DAL to NYC.
# From DAL to MKC.
# From DAL to ISP.
# From DAL to HOU.
# From DAL to MEM.
# From DAL to SJC.
# From DAL to LIT.
# From DAL to BOS.
# From DAL to SLC.
# From DAL to WAS.
# From DAL to SAN.
# From DAL to BNA.
# From DAL to PIT.
# From DAL to LAS.
# From DAL to CLT.
# From DAL to BHM.
# From DAL to ORL.
# From DAL to DSM.
# From DAL to CHI.
# From DAL to MIA.
# From DAL to AVP.
# From DAL to GSP.
# From DAL to JAN.
# From DAL to JAX.
# From DAL to LAN.
# From DAL to SJU.
# From DAL to BDL.
# From DAL to STL.
# From DAL to GYE.
# From DAL to MEX.
# From DAL to GDL.
# From DAL to TUS.
# From DAL to MSY.
# From DAL to DTT.
# From DAL to CMH.
# From DAL to MSP.
# From DAL to BJX.
# From DAL to RIC.
# From DAL to BQN.
# From DAL to VPS.
# From DAL to MFR.
# From DAL to LON.
# From DAL to HNL.
# From DAL to HAR.
# From DAL to BJS.
# From DAL to MKE.
# From DAL to BKG.
# From DAL to NAS.
# From DAL to COS.
# From DAL to PHX.
# From DAL to MLM.
# From DAL to BKK.
# From DAL to SGN.
# From DAL to YWG.
# From DAL to SYR.
# From DAL to GUA.
# From DAL to MOW.
# From DAL to FAY.
# From DAL to KTM.
# From DAL to NBO.
# From DAL to CHA.
# From DAL to HYD.
# From DAL to DEL.
# From DAL to HRB.
# From DAL to CJU.
# From DAL to LIM.
# From DAL to FYV.
# From DAL to GJT.
# From DAL to SYX.
# From DAL to MAD.
# From DAL to BEY.
# From DAL to BGW.
# From DAL to BCN.
# From DAL to WLG.
# From DAL to MTY.
# From DAL to KGL.
# Searching flights out of IND
# From IND to TPA.
# From IND to NYC.
# From IND to FMY.
# From IND to CHI.
# From IND to LAS.
# From IND to AUS.
# From IND to CUN.
# From IND to ISP.
# From IND to SFO.
# From IND to BUR.
# From IND to LAX.
# From IND to SAT.
# From IND to MEX.
# From IND to BIL.
# From IND to GEG.
# From IND to OAK.
# From IND to DUB.
# From IND to MYR.
# From IND to SLC.
# From IND to BRO.
# From IND to GRB.
# From IND to SJU.
# From IND to PHX.
# From IND to RGN.
# From IND to TYO.

# %%
prices_df
# Out:
#      Origin Destination        Purchase Time  Distance (Miles) Departure Date  \
# 0       ATL         ORL  2018-10-06T17:05:14               402     2018-11-12
# 1       ATL         MIA  2018-10-06T11:08:57               604     2019-02-06
# 2       ATL         PHL  2018-10-07T17:03:57               666     2018-10-20
# 3       ATL         DFW  2018-10-07T16:51:42               718     2018-11-14
# 4       ATL         MSY  2018-10-06T01:24:08               424     2018-12-14
# 5       ATL         FLL  2018-10-06T20:34:02               585     2018-10-20
# 6       ATL         CHI  2018-10-06T07:18:53               589     2018-10-30
# 7       ATL         BWI  2018-10-07T11:40:10               577     2018-11-02
# 8       ATL         HOU  2018-10-07T15:17:26               702     2018-10-23
# 9       ATL         BNA  2018-10-06T21:04:46               209     2018-12-23
# 10      ATL         NYC  2018-10-06T15:41:12               747     2018-10-27
# 11      ATL         LAS  2018-10-06T19:46:46              1746     2018-10-23
# 12      ATL         WAS  2018-10-07T01:32:11               542     2019-02-25
# 13      ATL         SAT  2018-10-05T19:41:52               882     2018-10-17
# 14      ATL         TPA  2018-10-07T17:25:56               417     2018-10-12
# 15      ATL         SEA  2018-10-05T21:59:12              2181     2018-10-23
# 16      ATL         PIT  2018-10-06T19:17:20               522     2019-01-01
# 17      ATL         LAX  2018-10-06T03:18:37              1935     2018-10-25
# 18      ATL         JAX  2018-10-06T16:50:41               285     2018-12-14
# 19      ATL         OAK  2018-10-07T00:22:12              2129     2018-10-20
# 20      ATL         MKC  2018-10-07T12:14:49               674     2018-10-10
# 21      ATL         GUA  2018-10-07T13:48:54              1380     2018-11-14
# 22      ATL         ISP  2018-10-06T15:41:12               788     2018-10-27
# 23      ATL         OKC  2018-10-06T09:01:25               756     2018-11-18
# 24      ATL         DTT  2018-10-06T23:06:09               598     2018-10-21
# 25      ATL         OMA  2018-10-07T07:18:07               820     2018-11-19
# 26      ATL         MLB  2018-10-07T15:00:06               449     2018-11-15
# 27      ATL         STI  2018-10-06T18:35:07              1305     2018-11-08
# 28      ATL         FSD  2018-10-05T21:57:46               950     2018-10-19
# 29      ATL         SDQ  2018-10-07T03:19:33              1380     2018-11-14
# ...     ...         ...                  ...               ...            ...
# 3368    DAL         BGW  2018-10-05T20:47:30              7224     2018-10-25
# 3369    DAL         BCN  2018-10-06T20:49:08              5183     2019-09-02
# 3370    DAL         WLG  2018-10-06T12:49:26              7603     2019-06-15
# 3371    DAL         MTY  2018-10-06T19:21:43               537     2018-12-21
# 3372    DAL         KGL  2018-10-06T08:19:46              8408     2018-12-13
# 3373    IND         TPA  2018-10-06T23:47:39               842     2018-10-31
# 3374    IND         NYC  2018-10-07T15:48:00               652     2018-11-08
# 3375    IND         FMY  2018-10-07T00:40:28               942     2018-12-03
# 3376    IND         CHI  2018-10-05T23:25:08               165     2018-10-19
# 3377    IND         LAS  2018-10-06T10:14:26              1588     2018-10-23
# 3378    IND         AUS  2018-10-06T05:19:27               919     2018-10-15
# 3379    IND         CUN  2018-10-05T20:29:17              1292     2019-01-05
# 3380    IND         ISP  2018-10-07T15:48:00               700     2018-11-08
# 3381    IND         SFO  2018-10-07T09:24:07              1940     2018-10-16
# 3382    IND         BUR  2018-10-07T05:37:27              1802     2018-11-04
# 3383    IND         LAX  2018-10-07T05:39:08              1800     2018-11-04
# 3384    IND         SAT  2018-10-06T05:18:54               993     2018-10-15
# 3385    IND         MEX  2018-10-07T00:16:08              1597     2018-12-18
# 3386    IND         BIL  2018-10-06T22:13:48              1200     2019-01-02
# 3387    IND         GEG  2018-10-06T20:42:22              1638     2018-10-13
# 3388    IND         OAK  2018-10-07T09:24:07              1932     2018-10-16
# 3389    IND         DUB  2018-10-05T20:39:18              3713     2018-11-07
# 3390    IND         MYR  2018-10-06T12:45:44               584     2019-04-19
# 3391    IND         SLC  2018-10-06T07:19:13              1353     2018-10-14
# 3392    IND         BRO  2018-10-07T13:44:20              1151     2018-10-20
# 3393    IND         GRB  2018-10-05T19:39:00               343     2018-10-16
# 3394    IND         SJU  2018-10-05T18:51:34              1901     2018-12-20
# 3395    IND         PHX  2018-10-07T15:05:52              1490     2018-10-07
# 3396    IND         RGN  2018-10-06T19:05:49              8533     2019-02-28
# 3397    IND         TYO  2018-10-07T07:14:17              6469     2018-12-01
#
#       Price (USD)  Class     Purchase Gate
# 0           24.00      0          Kiwi.com
# 1           40.78      0        eDreams US
# 2           48.64      0    CompassFlights
# 3           48.64      0    CompassFlights
# 4           51.20      0           JustFly
# 5           51.20      0           JustFly
# 6           56.18      0           JustFly
# 7           56.73      0     FlightNetwork
# 8           59.15      0        SmartFares
# 9           66.97      0        MyHolidays
# 10          71.19      0  Cheaptickets.com
# 11          76.19      0           JustFly
# 12          88.55      0    CompassFlights
# 13          89.77      0          Kiwi.com
# 14          90.19      0           JustFly
# 15          92.61      0     FlightNetwork
# 16          92.82      0        MyHolidays
# 17          99.18      0           JustFly
# 18          99.97      0        MyHolidays
# 19         107.21      0     FlightNetwork
# 20         110.77      0  Cheaptickets.com
# 21         111.08      0     FlightNetwork
# 22         112.52      0     FlightNetwork
# 23         116.00      0          Kiwi.com
# 24         121.57      0    CompassFlights
# 25         128.00      0          Kiwi.com
# 26         133.52      0    CompassFlights
# 27         133.73      0            FlyFar
# 28         141.11      0          Kiwi.com
# 29         145.87      0        SmartFares
# ...           ...    ...               ...
# 3368       966.92      0            Vayama
# 3369       992.99      0     Justairticket
# 3370      1035.39      0            FlyFar
# 3371      1532.38      0           JustFly
# 3372      1610.10      0     Justairticket
# 3373        42.54      0     FlightNetwork
# 3374        95.19      0        MyHolidays
# 3375        97.71      0    CompassFlights
# 3376        99.37      0          Kiwi.com
# 3377       105.20      0         OneTravel
# 3378       113.99      0          Kiwi.com
# 3379       120.22      0        Mytrip.com
# 3380       142.52      0     FlightNetwork
# 3381       166.00      0          Kiwi.com
# 3382       169.15      0        MyHolidays
# 3383       173.52      0     FlightNetwork
# 3384       174.51      0        MyHolidays
# 3385       238.40      0        SmartFares
# 3386       243.99      0          Kiwi.com
# 3387       249.03      0        MyHolidays
# 3388       251.70      0     FlightNetwork
# 3389       252.33      0     FlightNetwork
# 3390       267.85      0    CompassFlights
# 3391       293.98      0        MyHolidays
# 3392       320.50      0          Kiwi.com
# 3393       358.74      0          Kiwi.com
# 3394       391.90      0        MyHolidays
# 3395       512.00      0          Kiwi.com
# 3396       656.99      0            Vayama
# 3397       708.99      0            Vayama
#
# [3398 rows x 8 columns]

# %%
prices_df.to_csv("Output/Prices3.csv")

# %%
pulls=['Prices2.csv','Prices3.csv']
allprices_df=pd.read_csv('Output/Prices.csv')
for pull in pulls:
    currprices=pd.read_csv('Output/'+pull)
    allprices_df=allprices_df.append(currprices)
allprices_df.reset_index(drop=True)
allprices_df=allprices_df.drop(columns=['Unnamed: 0'])
allprices_df
# Out:
#      Origin Destination        Purchase Time  Distance (Miles) Departure Date  \
# 0       ATL         ORL  2018-10-01T18:46:04               402     2018-10-30
# 1       ATL         BWI  2018-10-02T15:48:55               577     2018-10-23
# 2       ATL         FLL  2018-10-01T23:19:24               585     2018-10-09
# 3       ATL         DFW  2018-10-01T16:08:11               718     2018-10-24
# 4       ATL         HOU  2018-10-02T22:09:02               702     2018-10-09
# 5       ATL         MIA  2018-10-01T13:16:48               604     2018-10-18
# 6       ATL         CHI  2018-10-02T01:42:33               589     2018-10-25
# 7       ATL         RDU  2018-10-02T20:50:17               349     2019-01-03
# 8       ATL         BOS  2018-10-01T23:33:11               937     2018-10-28
# 9       ATL         TPA  2018-10-03T00:14:18               417     2018-10-12
# 10      ATL         NYC  2018-10-02T10:59:45               747     2018-10-30
# 11      ATL         PIT  2018-10-01T18:38:03               522     2018-10-11
# 12      ATL         BNA  2018-10-02T01:54:02               209     2018-12-30
# 13      ATL         DEN  2018-10-01T17:09:09              1211     2018-12-17
# 14      ATL         MSY  2018-10-02T05:04:54               424     2018-10-19
# 15      ATL         RIC  2018-10-02T20:41:48               469     2018-10-09
# 16      ATL         DTT  2018-10-02T19:46:51               598     2018-10-11
# 17      ATL         COS  2018-10-02T21:50:43              1189     2018-10-11
# 18      ATL         LAS  2018-10-02T22:42:28              1746     2018-10-24
# 19      ATL         HOT  2018-10-02T13:19:02               498     2018-11-02
# 20      ATL         LAX  2018-10-02T04:09:58              1935     2018-12-07
# 21      ATL         JAX  2018-10-02T10:33:17               285     2018-12-14
# 22      ATL         MEM  2018-10-02T13:19:10               336     2018-11-02
# 23      ATL         SJU  2018-10-01T19:50:02              1546     2018-12-02
# 24      ATL         AUS  2018-10-02T02:29:47               819     2018-12-24
# 25      ATL         SEA  2018-10-02T00:08:53              2181     2018-10-16
# 26      ATL         ISP  2018-10-01T21:10:11               788     2018-12-14
# 27      ATL         SAN  2018-10-02T10:31:06              1889     2018-10-13
# 28      ATL         WAS  2018-10-01T18:38:01               542     2018-10-11
# 29      ATL         JAN  2018-10-01T13:07:31               351     2018-10-12
# ...     ...         ...                  ...               ...            ...
# 3368    DAL         BGW  2018-10-05T20:47:30              7224     2018-10-25
# 3369    DAL         BCN  2018-10-06T20:49:08              5183     2019-09-02
# 3370    DAL         WLG  2018-10-06T12:49:26              7603     2019-06-15
# 3371    DAL         MTY  2018-10-06T19:21:43               537     2018-12-21
# 3372    DAL         KGL  2018-10-06T08:19:46              8408     2018-12-13
# 3373    IND         TPA  2018-10-06T23:47:39               842     2018-10-31
# 3374    IND         NYC  2018-10-07T15:48:00               652     2018-11-08
# 3375    IND         FMY  2018-10-07T00:40:28               942     2018-12-03
# 3376    IND         CHI  2018-10-05T23:25:08               165     2018-10-19
# 3377    IND         LAS  2018-10-06T10:14:26              1588     2018-10-23
# 3378    IND         AUS  2018-10-06T05:19:27               919     2018-10-15
# 3379    IND         CUN  2018-10-05T20:29:17              1292     2019-01-05
# 3380    IND         ISP  2018-10-07T15:48:00               700     2018-11-08
# 3381    IND         SFO  2018-10-07T09:24:07              1940     2018-10-16
# 3382    IND         BUR  2018-10-07T05:37:27              1802     2018-11-04
# 3383    IND         LAX  2018-10-07T05:39:08              1800     2018-11-04
# 3384    IND         SAT  2018-10-06T05:18:54               993     2018-10-15
# 3385    IND         MEX  2018-10-07T00:16:08              1597     2018-12-18
# 3386    IND         BIL  2018-10-06T22:13:48              1200     2019-01-02
# 3387    IND         GEG  2018-10-06T20:42:22              1638     2018-10-13
# 3388    IND         OAK  2018-10-07T09:24:07              1932     2018-10-16
# 3389    IND         DUB  2018-10-05T20:39:18              3713     2018-11-07
# 3390    IND         MYR  2018-10-06T12:45:44               584     2019-04-19
# 3391    IND         SLC  2018-10-06T07:19:13              1353     2018-10-14
# 3392    IND         BRO  2018-10-07T13:44:20              1151     2018-10-20
# 3393    IND         GRB  2018-10-05T19:39:00               343     2018-10-16
# 3394    IND         SJU  2018-10-05T18:51:34              1901     2018-12-20
# 3395    IND         PHX  2018-10-07T15:05:52              1490     2018-10-07
# 3396    IND         RGN  2018-10-06T19:05:49              8533     2019-02-28
# 3397    IND         TYO  2018-10-07T07:14:17              6469     2018-12-01
#
#       Price (USD)  Class   Purchase Gate
# 0           23.50      0        Kiwi.com
# 1           28.97      0       OneTravel
# 2           28.97      0       OneTravel
# 3           48.65      0  CompassFlights
# 4           51.99      0         JustFly
# 5           54.21      0       OneTravel
# 6           56.18      0         JustFly
# 7           56.76      0   FlightNetwork
# 8           61.09      0  CompassFlights
# 9           61.41      0   FlightNetwork
# 10          67.74      0   FlightNetwork
# 11          68.01      0        Kiwi.com
# 12          70.47      0      MyHolidays
# 13          71.61      0      SmartFares
# 14          72.76      0      SmartFares
# 15          85.44      0       OneTravel
# 16          86.01      0      MyHolidays
# 17          91.99      0        Kiwi.com
# 18          98.77      0         JustFly
# 19          99.06      0       OneTravel
# 20          99.18      0         JustFly
# 21         101.38      0      MyHolidays
# 22         106.99      0        Kiwi.com
# 23         109.43      0          FlyFar
# 24         110.12      0  CompassFlights
# 25         111.31      0   FlightNetwork
# 26         112.50      0   FlightNetwork
# 27         112.99      0        Kiwi.com
# 28         115.01      0        Kiwi.com
# 29         123.65      0      SmartFares
# ...           ...    ...             ...
# 3368       966.92      0          Vayama
# 3369       992.99      0   Justairticket
# 3370      1035.39      0          FlyFar
# 3371      1532.38      0         JustFly
# 3372      1610.10      0   Justairticket
# 3373        42.54      0   FlightNetwork
# 3374        95.19      0      MyHolidays
# 3375        97.71      0  CompassFlights
# 3376        99.37      0        Kiwi.com
# 3377       105.20      0       OneTravel
# 3378       113.99      0        Kiwi.com
# 3379       120.22      0      Mytrip.com
# 3380       142.52      0   FlightNetwork
# 3381       166.00      0        Kiwi.com
# 3382       169.15      0      MyHolidays
# 3383       173.52      0   FlightNetwork
# 3384       174.51      0      MyHolidays
# 3385       238.40      0      SmartFares
# 3386       243.99      0        Kiwi.com
# 3387       249.03      0      MyHolidays
# 3388       251.70      0   FlightNetwork
# 3389       252.33      0   FlightNetwork
# 3390       267.85      0  CompassFlights
# 3391       293.98      0      MyHolidays
# 3392       320.50      0        Kiwi.com
# 3393       358.74      0        Kiwi.com
# 3394       391.90      0      MyHolidays
# 3395       512.00      0        Kiwi.com
# 3396       656.99      0          Vayama
# 3397       708.99      0          Vayama
#
# [11216 rows x 8 columns]

# %%
allprices_df.reset_index(drop=True)
# Out:
#        Unnamed: 0 Origin Destination        Purchase Time  Distance (Miles)  \
# 0               0    ATL         ORL  2018-10-01T18:46:04               402
# 1               1    ATL         BWI  2018-10-02T15:48:55               577
# 2               2    ATL         FLL  2018-10-01T23:19:24               585
# 3               3    ATL         DFW  2018-10-01T16:08:11               718
# 4               4    ATL         HOU  2018-10-02T22:09:02               702
# 5               5    ATL         MIA  2018-10-01T13:16:48               604
# 6               6    ATL         CHI  2018-10-02T01:42:33               589
# 7               7    ATL         RDU  2018-10-02T20:50:17               349
# 8               8    ATL         BOS  2018-10-01T23:33:11               937
# 9               9    ATL         TPA  2018-10-03T00:14:18               417
# 10             10    ATL         NYC  2018-10-02T10:59:45               747
# 11             11    ATL         PIT  2018-10-01T18:38:03               522
# 12             12    ATL         BNA  2018-10-02T01:54:02               209
# 13             13    ATL         DEN  2018-10-01T17:09:09              1211
# 14             14    ATL         MSY  2018-10-02T05:04:54               424
# 15             15    ATL         RIC  2018-10-02T20:41:48               469
# 16             16    ATL         DTT  2018-10-02T19:46:51               598
# 17             17    ATL         COS  2018-10-02T21:50:43              1189
# 18             18    ATL         LAS  2018-10-02T22:42:28              1746
# 19             19    ATL         HOT  2018-10-02T13:19:02               498
# 20             20    ATL         LAX  2018-10-02T04:09:58              1935
# 21             21    ATL         JAX  2018-10-02T10:33:17               285
# 22             22    ATL         MEM  2018-10-02T13:19:10               336
# 23             23    ATL         SJU  2018-10-01T19:50:02              1546
# 24             24    ATL         AUS  2018-10-02T02:29:47               819
# 25             25    ATL         SEA  2018-10-02T00:08:53              2181
# 26             26    ATL         ISP  2018-10-01T21:10:11               788
# 27             27    ATL         SAN  2018-10-02T10:31:06              1889
# 28             28    ATL         WAS  2018-10-01T18:38:01               542
# 29             29    ATL         JAN  2018-10-01T13:07:31               351
# ...           ...    ...         ...                  ...               ...
# 11186        3368    DAL         BGW  2018-10-05T20:47:30              7224
# 11187        3369    DAL         BCN  2018-10-06T20:49:08              5183
# 11188        3370    DAL         WLG  2018-10-06T12:49:26              7603
# 11189        3371    DAL         MTY  2018-10-06T19:21:43               537
# 11190        3372    DAL         KGL  2018-10-06T08:19:46              8408
# 11191        3373    IND         TPA  2018-10-06T23:47:39               842
# 11192        3374    IND         NYC  2018-10-07T15:48:00               652
# 11193        3375    IND         FMY  2018-10-07T00:40:28               942
# 11194        3376    IND         CHI  2018-10-05T23:25:08               165
# 11195        3377    IND         LAS  2018-10-06T10:14:26              1588
# 11196        3378    IND         AUS  2018-10-06T05:19:27               919
# 11197        3379    IND         CUN  2018-10-05T20:29:17              1292
# 11198        3380    IND         ISP  2018-10-07T15:48:00               700
# 11199        3381    IND         SFO  2018-10-07T09:24:07              1940
# 11200        3382    IND         BUR  2018-10-07T05:37:27              1802
# 11201        3383    IND         LAX  2018-10-07T05:39:08              1800
# 11202        3384    IND         SAT  2018-10-06T05:18:54               993
# 11203        3385    IND         MEX  2018-10-07T00:16:08              1597
# 11204        3386    IND         BIL  2018-10-06T22:13:48              1200
# 11205        3387    IND         GEG  2018-10-06T20:42:22              1638
# 11206        3388    IND         OAK  2018-10-07T09:24:07              1932
# 11207        3389    IND         DUB  2018-10-05T20:39:18              3713
# 11208        3390    IND         MYR  2018-10-06T12:45:44               584
# 11209        3391    IND         SLC  2018-10-06T07:19:13              1353
# 11210        3392    IND         BRO  2018-10-07T13:44:20              1151
# 11211        3393    IND         GRB  2018-10-05T19:39:00               343
# 11212        3394    IND         SJU  2018-10-05T18:51:34              1901
# 11213        3395    IND         PHX  2018-10-07T15:05:52              1490
# 11214        3396    IND         RGN  2018-10-06T19:05:49              8533
# 11215        3397    IND         TYO  2018-10-07T07:14:17              6469
#
#       Departure Date  Price (USD)  Class   Purchase Gate
# 0         2018-10-30        23.50      0        Kiwi.com
# 1         2018-10-23        28.97      0       OneTravel
# 2         2018-10-09        28.97      0       OneTravel
# 3         2018-10-24        48.65      0  CompassFlights
# 4         2018-10-09        51.99      0         JustFly
# 5         2018-10-18        54.21      0       OneTravel
# 6         2018-10-25        56.18      0         JustFly
# 7         2019-01-03        56.76      0   FlightNetwork
# 8         2018-10-28        61.09      0  CompassFlights
# 9         2018-10-12        61.41      0   FlightNetwork
# 10        2018-10-30        67.74      0   FlightNetwork
# 11        2018-10-11        68.01      0        Kiwi.com
# 12        2018-12-30        70.47      0      MyHolidays
# 13        2018-12-17        71.61      0      SmartFares
# 14        2018-10-19        72.76      0      SmartFares
# 15        2018-10-09        85.44      0       OneTravel
# 16        2018-10-11        86.01      0      MyHolidays
# 17        2018-10-11        91.99      0        Kiwi.com
# 18        2018-10-24        98.77      0         JustFly
# 19        2018-11-02        99.06      0       OneTravel
# 20        2018-12-07        99.18      0         JustFly
# 21        2018-12-14       101.38      0      MyHolidays
# 22        2018-11-02       106.99      0        Kiwi.com
# 23        2018-12-02       109.43      0          FlyFar
# 24        2018-12-24       110.12      0  CompassFlights
# 25        2018-10-16       111.31      0   FlightNetwork
# 26        2018-12-14       112.50      0   FlightNetwork
# 27        2018-10-13       112.99      0        Kiwi.com
# 28        2018-10-11       115.01      0        Kiwi.com
# 29        2018-10-12       123.65      0      SmartFares
# ...              ...          ...    ...             ...
# 11186     2018-10-25       966.92      0          Vayama
# 11187     2019-09-02       992.99      0   Justairticket
# 11188     2019-06-15      1035.39      0          FlyFar
# 11189     2018-12-21      1532.38      0         JustFly
# 11190     2018-12-13      1610.10      0   Justairticket
# 11191     2018-10-31        42.54      0   FlightNetwork
# 11192     2018-11-08        95.19      0      MyHolidays
# 11193     2018-12-03        97.71      0  CompassFlights
# 11194     2018-10-19        99.37      0        Kiwi.com
# 11195     2018-10-23       105.20      0       OneTravel
# 11196     2018-10-15       113.99      0        Kiwi.com
# 11197     2019-01-05       120.22      0      Mytrip.com
# 11198     2018-11-08       142.52      0   FlightNetwork
# 11199     2018-10-16       166.00      0        Kiwi.com
# 11200     2018-11-04       169.15      0      MyHolidays
# 11201     2018-11-04       173.52      0   FlightNetwork
# 11202     2018-10-15       174.51      0      MyHolidays
# 11203     2018-12-18       238.40      0      SmartFares
# 11204     2019-01-02       243.99      0        Kiwi.com
# 11205     2018-10-13       249.03      0      MyHolidays
# 11206     2018-10-16       251.70      0   FlightNetwork
# 11207     2018-11-07       252.33      0   FlightNetwork
# 11208     2019-04-19       267.85      0  CompassFlights
# 11209     2018-10-14       293.98      0      MyHolidays
# 11210     2018-10-20       320.50      0        Kiwi.com
# 11211     2018-10-16       358.74      0        Kiwi.com
# 11212     2018-12-20       391.90      0      MyHolidays
# 11213     2018-10-07       512.00      0        Kiwi.com
# 11214     2019-02-28       656.99      0          Vayama
# 11215     2018-12-01       708.99      0          Vayama
#
# [11216 rows x 9 columns]

# %%
allprices_df.to_csv("Output/AllPrices.csv")

# %%
origin='ATL'
print(f"Searching flights out of {origin}")
prices_url=f"http://api.travelpayouts.com/v2/prices/latest?currency=usd&limit=1000&origin={origin}&one_way=true"
headers = {"X-Access-Token": "f2b1a8fac25474496ea091529cddd0ec",
         }
prices_data = requests.get(prices_url, headers=headers).json()
# Out:
# Searching flights out of ATL

# %%
pprint(prices_data)
# Out:
# {'data': [{'actual': True,
#            'depart_date': '2018-10-29',
#            'destination': 'ORL',
#            'distance': 647,
#            'duration': 92,
#            'found_at': '2018-10-06T23:17:46',
#            'gate': 'Kiwi.com',
#            'number_of_changes': 0,
#            'origin': 'ATL',
#            'return_date': None,
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 24.0},
#           {'actual': True,
#            'depart_date': '2018-10-16',
#            'destination': 'PHL',
#            'distance': 1072,
#            'duration': 122,
#            'found_at': '2018-10-07T02:35:11',
#            'gate': 'CompassFlights',
#            'number_of_changes': 0,
#            'origin': 'ATL',
#            'return_date': None,
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 48.64},
#           {'actual': True,
#            'depart_date': '2018-11-14',
#            'destination': 'DFW',
#            'distance': 1156,
#            'duration': 152,
#            'found_at': '2018-10-08T17:44:43',
#            'gate': 'CompassFlights',
#            'number_of_changes': 0,
#            'origin': 'ATL',
#            'return_date': None,
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 48.64},
#           {'actual': True,
#            'depart_date': '2018-12-06',
#            'destination': 'FLL',
#            'distance': 942,
#            'duration': 111,
#            'found_at': '2018-10-08T20:47:52',
#            'gate': 'FlightNetwork',
#            'number_of_changes': 0,
#            'origin': 'ATL',
#            'return_date': None,
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 52.76},
#           {'actual': True,
#            'depart_date': '2018-10-17',
#            'destination': 'HOU',
#            'distance': 1131,
#            'duration': 131,
#            'found_at': '2018-10-08T02:30:59',
#            'gate': 'JustFly',
#            'number_of_changes': 0,
#            'origin': 'ATL',
#            'return_date': None,
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 54.18},
#           {'actual': True,
#            'depart_date': '2018-11-02',
#            'destination': 'TPA',
#            'distance': 671,
#            'duration': 87,
#            'found_at': '2018-10-07T22:28:57',
#            'gate': 'JustFly',
#            'number_of_changes': 0,
#            'origin': 'ATL',
#            'return_date': None,
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 55.19},
#           {'actual': True,
#            'depart_date': '2018-12-15',
#            'destination': 'CHI',
#            'distance': 949,
#            'duration': 129,
#            'found_at': '2018-10-07T17:48:32',
#            'gate': 'JustFly',
#            'number_of_changes': 0,
#            'origin': 'ATL',
#            'return_date': None,
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 56.19},
#           {'actual': True,
#            'depart_date': '2018-11-02',
#            'destination': 'BWI',
#            'distance': 929,
#            'duration': 108,
#            'found_at': '2018-10-07T11:40:10',
#            'gate': 'FlightNetwork',
#            'number_of_changes': 0,
#            'origin': 'ATL',
#            'return_date': None,
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 56.73},
#           {'actual': True,
#            'depart_date': '2018-12-06',
#            'destination': 'MIA',
#            'distance': 973,
#            'duration': 114,
#            'found_at': '2018-10-08T20:47:52',
#            'gate': 'Vayama',
#            'number_of_changes': 0,
#            'origin': 'ATL',
#            'return_date': None,
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 59.0},
#           {'actual': True,
#            'depart_date': '2018-12-23',
#            'destination': 'BNA',
#            'distance': 337,
#            'duration': 65,
#            'found_at': '2018-10-06T21:04:46',
#            'gate': 'MyHolidays',
#            'number_of_changes': 0,
#            'origin': 'ATL',
#            'return_date': None,
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 66.97},
#           {'actual': True,
#            'depart_date': '2018-10-13',
#            'destination': 'CVG',
#            'distance': 594,
#            'duration': 92,
#            'found_at': '2018-10-07T22:32:56',
#            'gate': 'SmartFares',
#            'number_of_changes': 0,
#            'origin': 'ATL',
#            'return_date': None,
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 73.14},
#           {'actual': True,
#            'depart_date': '2018-10-23',
#            'destination': 'LAS',
#            'distance': 2810,
#            'duration': 263,
#            'found_at': '2018-10-08T11:25:07',
#            'gate': 'JustFly',
#            'number_of_changes': 0,
#            'origin': 'ATL',
#            'return_date': None,
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 76.19},
#           {'actual': True,
#            'depart_date': '2018-10-24',
#            'destination': 'NYC',
#            'distance': 1202,
#            'duration': 129,
#            'found_at': '2018-10-07T11:54:56',
#            'gate': 'Kiwi.com',
#            'number_of_changes': 0,
#            'origin': 'ATL',
#            'return_date': None,
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 77.31},
#           {'actual': True,
#            'depart_date': '2018-10-22',
#            'destination': 'PIT',
#            'distance': 841,
#            'duration': 1330,
#            'found_at': '2018-10-08T17:13:30',
#            'gate': 'Kiwi.com',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': None,
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 82.5},
#           {'actual': True,
#            'depart_date': '2019-03-25',
#            'destination': 'WAS',
#            'distance': 873,
#            'duration': 109,
#            'found_at': '2018-10-07T18:59:16',
#            'gate': 'Билетик Аэро',
#            'number_of_changes': 0,
#            'origin': 'ATL',
#            'return_date': None,
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 88.33},
#           {'actual': True,
#            'depart_date': '2018-10-25',
#            'destination': 'SJU',
#            'distance': 2489,
#            'duration': 218,
#            'found_at': '2018-10-08T02:17:27',
#            'gate': 'Kiwi.com',
#            'number_of_changes': 0,
#            'origin': 'ATL',
#            'return_date': None,
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 91.0},
#           {'actual': True,
#            'depart_date': '2018-10-25',
#            'destination': 'LYH',
#            'distance': 616,
#            'duration': 305,
#            'found_at': '2018-10-08T09:49:24',
#            'gate': 'CompassFlights',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': None,
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 91.88},
#           {'actual': True,
#            'depart_date': '2018-11-05',
#            'destination': 'LAX',
#            'distance': 3114,
#            'duration': 286,
#            'found_at': '2018-10-08T16:29:40',
#            'gate': 'JustFly',
#            'number_of_changes': 0,
#            'origin': 'ATL',
#            'return_date': None,
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 99.18},
#           {'actual': True,
#            'depart_date': '2019-02-25',
#            'destination': 'JAN',
#            'distance': 565,
#            'duration': 822,
#            'found_at': '2018-10-08T00:14:19',
#            'gate': 'Kiwi.com',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': None,
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 104.0},
#           {'actual': True,
#            'depart_date': '2018-10-20',
#            'destination': 'OAK',
#            'distance': 3427,
#            'duration': 573,
#            'found_at': '2018-10-07T00:22:12',
#            'gate': 'FlightNetwork',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': None,
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 107.21},
#           {'actual': True,
#            'depart_date': '2018-11-14',
#            'destination': 'GUA',
#            'distance': 2221,
#            'duration': 502,
#            'found_at': '2018-10-07T13:48:54',
#            'gate': 'FlightNetwork',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': None,
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 111.08},
#           {'actual': True,
#            'depart_date': '2018-11-01',
#            'destination': 'ISP',
#            'distance': 1269,
#            'duration': 260,
#            'found_at': '2018-10-08T19:28:04',
#            'gate': 'FlightNetwork',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': None,
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 112.52},
#           {'actual': True,
#            'depart_date': '2018-10-20',
#            'destination': 'SAN',
#            'distance': 3041,
#            'duration': 1776,
#            'found_at': '2018-10-07T20:51:41',
#            'gate': 'Kiwi.com',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': None,
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 112.99},
#           {'actual': True,
#            'depart_date': '2018-11-18',
#            'destination': 'OKC',
#            'distance': 1217,
#            'duration': 315,
#            'found_at': '2018-10-08T04:11:43',
#            'gate': 'MyHolidays',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': None,
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 115.7},
#           {'actual': True,
#            'depart_date': '2019-06-15',
#            'destination': 'CMH',
#            'distance': 702,
#            'duration': 281,
#            'found_at': '2018-10-08T13:40:52',
#            'gate': 'CompassFlights',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': None,
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 118.9},
#           {'actual': True,
#            'depart_date': '2018-10-21',
#            'destination': 'DTT',
#            'distance': 963,
#            'duration': 313,
#            'found_at': '2018-10-06T23:06:09',
#            'gate': 'CompassFlights',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': None,
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 121.57},
#           {'actual': True,
#            'depart_date': '2018-11-19',
#            'destination': 'OMA',
#            'distance': 1320,
#            'duration': 823,
#            'found_at': '2018-10-07T07:18:07',
#            'gate': 'Kiwi.com',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': None,
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 128.0},
#           {'actual': True,
#            'depart_date': '2018-10-26',
#            'destination': 'EYW',
#            'distance': 1054,
#            'duration': 297,
#            'found_at': '2018-10-08T14:33:34',
#            'gate': 'CompassFlights',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': None,
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 128.19},
#           {'actual': True,
#            'depart_date': '2018-11-15',
#            'destination': 'MLB',
#            'distance': 724,
#            'duration': 352,
#            'found_at': '2018-10-07T15:00:06',
#            'gate': 'CompassFlights',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': None,
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 133.52},
#           {'actual': True,
#            'depart_date': '2018-10-15',
#            'destination': 'HAR',
#            'distance': 983,
#            'duration': 914,
#            'found_at': '2018-10-08T20:17:19',
#            'gate': 'OneTravel',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': None,
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 136.4},
#           {'actual': True,
#            'depart_date': '2018-11-25',
#            'destination': 'LIT',
#            'distance': 729,
#            'duration': 1859,
#            'found_at': '2018-10-08T10:19:01',
#            'gate': 'OneTravel',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': None,
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 140.39},
#           {'actual': True,
#            'depart_date': '2019-02-25',
#            'destination': 'MEM',
#            'distance': 542,
#            'duration': 1061,
#            'found_at': '2018-10-08T00:14:21',
#            'gate': 'FareDepot',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': None,
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 141.4},
#           {'actual': True,
#            'depart_date': '2018-11-03',
#            'destination': 'SDF',
#            'distance': 516,
#            'duration': 574,
#            'found_at': '2018-10-08T05:07:22',
#            'gate': 'Kiwi.com',
#            'number_of_changes': 2,
#            'origin': 'ATL',
#            'return_date': None,
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 142.0},
#           {'actual': True,
#            'depart_date': '2018-11-14',
#            'destination': 'SDQ',
#            'distance': 2221,
#            'duration': 605,
#            'found_at': '2018-10-07T03:19:33',
#            'gate': 'SmartFares',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': None,
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 145.87},
#           {'actual': True,
#            'depart_date': '2018-10-17',
#            'destination': 'ABQ',
#            'distance': 2043,
#            'duration': 1586,
#            'found_at': '2018-10-07T22:01:02',
#            'gate': 'Kiwi.com',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': None,
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 147.0},
#           {'actual': True,
#            'depart_date': '2018-12-08',
#            'destination': 'MBJ',
#            'distance': 1816,
#            'duration': 395,
#            'found_at': '2018-10-08T18:59:17',
#            'gate': 'CompassFlights',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': None,
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 147.31},
#           {'actual': True,
#            'depart_date': '2018-10-30',
#            'destination': 'SEA',
#            'distance': 3510,
#            'duration': 1030,
#            'found_at': '2018-10-08T00:09:16',
#            'gate': 'Kiwi.com',
#            'number_of_changes': 2,
#            'origin': 'ATL',
#            'return_date': None,
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 147.99},
#           {'actual': True,
#            'depart_date': '2018-10-15',
#            'destination': 'IND',
#            'distance': 686,
#            'duration': 747,
#            'found_at': '2018-10-07T21:27:33',
#            'gate': 'Kiwi.com',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': None,
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 147.99},
#           {'actual': True,
#            'depart_date': '2018-10-30',
#            'destination': 'PDX',
#            'distance': 3489,
#            'duration': 959,
#            'found_at': '2018-10-07T04:11:30',
#            'gate': 'Kiwi.com',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': None,
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 148.99},
#           {'actual': True,
#            'depart_date': '2019-02-25',
#            'destination': 'AVP',
#            'distance': 1122,
#            'duration': 220,
#            'found_at': '2018-10-07T01:31:43',
#            'gate': 'MyHolidays',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': None,
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 150.27},
#           {'actual': True,
#            'depart_date': '2018-11-12',
#            'destination': 'JAC',
#            'distance': 2524,
#            'duration': 345,
#            'found_at': '2018-10-07T19:23:37',
#            'gate': 'City.Travel',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': None,
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 157.53},
#           {'actual': True,
#            'depart_date': '2018-10-20',
#            'destination': 'SFO',
#            'distance': 3441,
#            'duration': 505,
#            'found_at': '2018-10-07T00:22:13',
#            'gate': 'MyHolidays',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': None,
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 163.03},
#           {'actual': True,
#            'depart_date': '2019-02-25',
#            'destination': 'DUJ',
#            'distance': 971,
#            'duration': 440,
#            'found_at': '2018-10-07T01:31:50',
#            'gate': 'City.Travel',
#            'number_of_changes': 2,
#            'origin': 'ATL',
#            'return_date': None,
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 166.34},
#           {'actual': True,
#            'depart_date': '2019-02-25',
#            'destination': 'LNS',
#            'distance': 1021,
#            'duration': 420,
#            'found_at': '2018-10-07T01:32:12',
#            'gate': 'City.Travel',
#            'number_of_changes': 2,
#            'origin': 'ATL',
#            'return_date': None,
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 166.34},
#           {'actual': True,
#            'depart_date': '2018-10-15',
#            'destination': 'ABE',
#            'distance': 1104,
#            'duration': 700,
#            'found_at': '2018-10-08T00:25:38',
#            'gate': 'Kiwi.com',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': None,
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 166.99},
#           {'actual': True,
#            'depart_date': '2019-02-25',
#            'destination': 'FKL',
#            'distance': 951,
#            'duration': 365,
#            'found_at': '2018-10-07T01:31:55',
#            'gate': 'City.Travel',
#            'number_of_changes': 2,
#            'origin': 'ATL',
#            'return_date': None,
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 168.43},
#           {'actual': True,
#            'depart_date': '2018-12-26',
#            'destination': 'PTY',
#            'distance': 2800,
#            'duration': 761,
#            'found_at': '2018-10-07T01:37:15',
#            'gate': 'OneTravel',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': None,
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 168.84},
#           {'actual': True,
#            'depart_date': '2019-02-25',
#            'destination': 'HGR',
#            'distance': 902,
#            'duration': 460,
#            'found_at': '2018-10-07T01:31:58',
#            'gate': 'Vayama',
#            'number_of_changes': 2,
#            'origin': 'ATL',
#            'return_date': None,
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 170.7},
#           {'actual': True,
#            'depart_date': '2018-12-09',
#            'destination': 'GDL',
#            'distance': 2375,
#            'duration': 2627,
#            'found_at': '2018-10-07T19:58:39',
#            'gate': 'Kiwi.com',
#            'number_of_changes': 2,
#            'origin': 'ATL',
#            'return_date': None,
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 171.99},
#           {'actual': True,
#            'depart_date': '2019-02-25',
#            'destination': 'AOO',
#            'distance': 918,
#            'duration': 450,
#            'found_at': '2018-10-07T01:31:30',
#            'gate': 'Vayama',
#            'number_of_changes': 2,
#            'origin': 'ATL',
#            'return_date': None,
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 172.69},
#           {'actual': True,
#            'depart_date': '2019-02-25',
#            'destination': 'BFD',
#            'distance': 1041,
#            'duration': 600,
#            'found_at': '2018-10-07T01:31:38',
#            'gate': 'Vayama',
#            'number_of_changes': 2,
#            'origin': 'ATL',
#            'return_date': None,
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 172.69},
#           {'actual': True,
#            'depart_date': '2019-02-25',
#            'destination': 'MGW',
#            'distance': 768,
#            'duration': 600,
#            'found_at': '2018-10-07T01:32:18',
#            'gate': 'Vayama',
#            'number_of_changes': 2,
#            'origin': 'ATL',
#            'return_date': None,
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 172.69},
#           {'actual': True,
#            'depart_date': '2018-12-24',
#            'destination': 'MEX',
#            'distance': 2162,
#            'duration': 895,
#            'found_at': '2018-10-08T02:45:02',
#            'gate': 'OneTravel',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': None,
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 187.6},
#           {'actual': True,
#            'depart_date': '2018-11-26',
#            'destination': 'DEN',
#            'distance': 1949,
#            'duration': 663,
#            'found_at': '2018-10-08T03:31:18',
#            'gate': 'Kiwi.com',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': None,
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 212.99},
#           {'actual': True,
#            'depart_date': '2018-10-13',
#            'destination': 'LSE',
#            'distance': 1274,
#            'duration': 392,
#            'found_at': '2018-10-07T22:52:17',
#            'gate': 'MyHolidays',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': None,
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 227.9},
#           {'actual': True,
#            'depart_date': '2018-10-11',
#            'destination': 'AUS',
#            'distance': 1318,
#            'duration': 1107,
#            'found_at': '2018-10-08T17:06:45',
#            'gate': 'Kiwi.com',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': None,
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 241.99},
#           {'actual': True,
#            'depart_date': '2018-11-13',
#            'destination': 'AMS',
#            'distance': 7067,
#            'duration': 1275,
#            'found_at': '2018-10-08T00:31:30',
#            'gate': 'FlightNetwork',
#            'number_of_changes': 2,
#            'origin': 'ATL',
#            'return_date': None,
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 242.44},
#           {'actual': True,
#            'depart_date': '2018-10-21',
#            'destination': 'FNT',
#            'distance': 1028,
#            'duration': 370,
#            'found_at': '2018-10-06T23:04:26',
#            'gate': 'MyHolidays',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': None,
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 243.2},
#           {'actual': True,
#            'depart_date': '2018-10-20',
#            'destination': 'SMR',
#            'distance': 2712,
#            'duration': 1537,
#            'found_at': '2018-10-08T01:43:04',
#            'gate': 'Kiwi.com',
#            'number_of_changes': 2,
#            'origin': 'ATL',
#            'return_date': None,
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 252.99},
#           {'actual': True,
#            'depart_date': '2018-10-15',
#            'destination': 'JST',
#            'distance': 894,
#            'duration': 420,
#            'found_at': '2018-10-08T20:17:14',
#            'gate': 'MyHolidays',
#            'number_of_changes': 2,
#            'origin': 'ATL',
#            'return_date': None,
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 257.19},
#           {'actual': True,
#            'depart_date': '2018-10-18',
#            'destination': 'BOG',
#            'distance': 3403,
#            'duration': 385,
#            'found_at': '2018-10-08T13:13:49',
#            'gate': 'Vayama',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': None,
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 262.0},
#           {'actual': True,
#            'depart_date': '2019-01-08',
#            'destination': 'MLM',
#            'distance': 2259,
#            'duration': 1729,
#            'found_at': '2018-10-07T20:42:52',
#            'gate': 'MyHolidays',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': None,
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 270.0},
#           {'actual': True,
#            'depart_date': '2018-12-14',
#            'destination': 'QRO',
#            'distance': 2151,
#            'duration': 1444,
#            'found_at': '2018-10-07T14:07:19',
#            'gate': 'OneTravel',
#            'number_of_changes': 2,
#            'origin': 'ATL',
#            'return_date': None,
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 278.6},
#           {'actual': True,
#            'depart_date': '2018-10-21',
#            'destination': 'FAY',
#            'distance': 526,
#            'duration': 476,
#            'found_at': '2018-10-08T12:29:19',
#            'gate': 'MyHolidays',
#            'number_of_changes': 2,
#            'origin': 'ATL',
#            'return_date': None,
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 310.02},
#           {'actual': True,
#            'depart_date': '2018-10-19',
#            'destination': 'HNL',
#            'distance': 7238,
#            'duration': 2266,
#            'found_at': '2018-10-07T00:54:13',
#            'gate': 'Kiwi.com',
#            'number_of_changes': 2,
#            'origin': 'ATL',
#            'return_date': None,
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 324.0},
#           {'actual': True,
#            'depart_date': '2018-10-21',
#            'destination': 'PSC',
#            'distance': 3238,
#            'duration': 434,
#            'found_at': '2018-10-07T01:27:25',
#            'gate': 'Justairticket',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': None,
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 346.99},
#           {'actual': True,
#            'depart_date': '2019-03-10',
#            'destination': 'DUB',
#            'distance': 6320,
#            'duration': 1168,
#            'found_at': '2018-10-07T23:25:05',
#            'gate': 'Kiwi.com',
#            'number_of_changes': 2,
#            'origin': 'ATL',
#            'return_date': None,
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 372.51},
#           {'actual': True,
#            'depart_date': '2018-10-14',
#            'destination': 'BUH',
#            'distance': 8857,
#            'duration': 2005,
#            'found_at': '2018-10-07T22:57:50',
#            'gate': 'Kiwi.com',
#            'number_of_changes': 2,
#            'origin': 'ATL',
#            'return_date': None,
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 421.99},
#           {'actual': True,
#            'depart_date': '2018-10-15',
#            'destination': 'MUC',
#            'distance': 7697,
#            'duration': 2908,
#            'found_at': '2018-10-08T04:24:29',
#            'gate': 'OneTravel',
#            'number_of_changes': 2,
#            'origin': 'ATL',
#            'return_date': None,
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 450.72},
#           {'actual': True,
#            'depart_date': '2018-12-23',
#            'destination': 'MOW',
#            'distance': 8661,
#            'duration': 2855,
#            'found_at': '2018-10-08T08:39:40',
#            'gate': 'Kiwi.com',
#            'number_of_changes': 2,
#            'origin': 'ATL',
#            'return_date': None,
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 520.6},
#           {'actual': True,
#            'depart_date': '2018-10-14',
#            'destination': 'IST',
#            'distance': 9271,
#            'duration': 1470,
#            'found_at': '2018-10-08T00:37:14',
#            'gate': 'Kiwi.com',
#            'number_of_changes': 2,
#            'origin': 'ATL',
#            'return_date': None,
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 525.99},
#           {'actual': True,
#            'depart_date': '2018-12-23',
#            'destination': 'HRO',
#            'distance': 846,
#            'duration': 2080,
#            'found_at': '2018-10-06T21:04:32',
#            'gate': 'OneTravel',
#            'number_of_changes': 2,
#            'origin': 'ATL',
#            'return_date': None,
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 543.1},
#           {'actual': True,
#            'depart_date': '2018-11-22',
#            'destination': 'MAA',
#            'distance': 14584,
#            'duration': 1820,
#            'found_at': '2018-10-08T10:40:16',
#            'gate': 'SmartFares',
#            'number_of_changes': 2,
#            'origin': 'ATL',
#            'return_date': None,
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 568.24},
#           {'actual': True,
#            'depart_date': '2018-10-12',
#            'destination': 'AMM',
#            'distance': 10437,
#            'duration': 2575,
#            'found_at': '2018-10-08T19:12:04',
#            'gate': 'OneTravel',
#            'number_of_changes': 2,
#            'origin': 'ATL',
#            'return_date': None,
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 618.88},
#           {'actual': True,
#            'depart_date': '2018-12-09',
#            'destination': 'BOM',
#            'distance': 13679,
#            'duration': 1792,
#            'found_at': '2018-10-07T17:05:48',
#            'gate': 'OneTravel',
#            'number_of_changes': 2,
#            'origin': 'ATL',
#            'return_date': None,
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 632.0},
#           {'actual': True,
#            'depart_date': '2018-12-12',
#            'destination': 'ASM',
#            'distance': 11921,
#            'duration': 1225,
#            'found_at': '2018-10-08T13:07:16',
#            'gate': 'MyHolidays',
#            'number_of_changes': 2,
#            'origin': 'ATL',
#            'return_date': None,
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 640.85},
#           {'actual': True,
#            'depart_date': '2018-12-27',
#            'destination': 'PMW',
#            'distance': 6195,
#            'duration': 1565,
#            'found_at': '2018-10-08T12:44:21',
#            'gate': 'Kiwi.com',
#            'number_of_changes': 2,
#            'origin': 'ATL',
#            'return_date': None,
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 835.1},
#           {'actual': True,
#            'depart_date': '2019-09-07',
#            'destination': 'HYD',
#            'distance': 14062,
#            'duration': 1625,
#            'found_at': '2018-10-08T19:15:03',
#            'gate': 'Go2See',
#            'number_of_changes': 2,
#            'origin': 'ATL',
#            'return_date': None,
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 882.9},
#           {'actual': True,
#            'depart_date': '2019-09-10',
#            'destination': 'ACC',
#            'distance': 9138,
#            'duration': 2840,
#            'found_at': '2018-10-08T19:15:16',
#            'gate': 'Go2See',
#            'number_of_changes': 2,
#            'origin': 'ATL',
#            'return_date': None,
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 941.04}],
#  'success': True}
